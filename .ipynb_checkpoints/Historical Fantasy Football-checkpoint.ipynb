# %% [markdown]
# # What If Fantasy Football Had Been Around When The NFL Formed?

# %% [markdown]
# https://developer.sportradar.com/files/indexFootball.html?python#nfl-official-api-v2
#
# This endpoint retrieves the Seasonal Statistics for a season.
#
# https://api.sportradar.us/nfl-{access_level}{version}/seasontd/{year}/{nfl_season}/teams/{team_id}/statistics.{format}?api_key={your_api_key}
#
# Replace placeholders with the following query parameters:
#
# Parameter                 Description
# access_level	          Defines the access level of your API key as Production (o), Trial (ot), or Simulation (sim).
#                           For more information on simulations, see NFL Official API v2 Simulations.
# version	                  Version number of the API you are accessing (current version: 2).
# year	                  Year in 4 digit format (YYYY).
# nfl_season	              Preseason (PRE), Regular Season (REG), or Post-Season (PST).
# team_id	                  ID of a given team.
# format	                  xml or json.
# your_api_key	          Your API key.

# %%
# Importing Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
import os
import json
import numpy as np
import seaborn as sb
import time

# %%
#api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}
api_dir = os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.realpath('__file__')))))
file_name = os.path.join(api_dir, "api_keys.json")
data = json.load(open(file_name))

c_key = data['sportradar_nfl_classic_key']
o_key = data['sportradar_nfl_official_key']

# %%
# https://api.sportradar.us/nfl-ot2/seasontd/{year}/
#         {nfl_season}/teams/{team_id}/statistics.{format}?api_key={your_api_key}

url = "http://api.sportradar.us/nfl-ot2/seasontd/"
season = "REG"
year = "2017"
output_format = "json"
team_id = "33405046-04ee-4058-a950-d606f8c30852"

query_url = url + year + "/" + season + "/teams/" + team_id + "/statistics." + output_format + "?api_key=" + o_key
nfl_response = requests.get(query_url)
nfl_json = nfl_response.json()

print(json.dumps(nfl_json, indent=4))
# Out:
# {
#     "id": "33405046-04ee-4058-a950-d606f8c30852",
#     "name": "Vikings",
#     "market": "Minnesota",
#     "alias": "MIN",
#     "season": {
#         "id": "3cf0e8ec-048d-4872-a706-b248c198831c",
#         "year": 2017,
#         "type": "REG",
#         "name": "REG"
#     },
#     "record": {
#         "games_played": 16,
#         "touchdowns": {
#             "pass": 25,
#             "rush": 15,
#             "total_return": 1,
#             "total": 41,
#             "fumble_return": 0,
#             "int_return": 1,
#             "kick_return": 0,
#             "punt_return": 0,
#             "other": 0
#         },
#         "rushing": {
#             "avg_yards": 3.906,
#             "attempts": 501,
#             "touchdowns": 15,
#             "tlost": 55,
#             "tlost_yards": -135,
#             "yards": 1957,
#             "longest": 58,
#             "longest_touchdown": 58,
#             "redzone_attempts": 25,
#             "broken_tackles": 33,
#             "kneel_downs": 21,
#             "scrambles": 17,
#             "yards_after_contact": 701
#         },
#         "receiving": {
#             "targets": 521,
#             "receptions": 357,
#             "avg_yards": 11.006,
#             "yards": 3929,
#             "touchdowns": 25,
#             "yards_after_catch": 1985,
#             "longest": 65,
#             "longest_touchdown": 65,
#             "redzone_targets": 28,
#             "air_yards": 1944,
#             "broken_tackles": 11,
#             "dropped_passes": 20,
#             "catchable_passes": 27,
#             "yards_after_contact": 359
#         },
#         "punts": {
#             "attempts": 71,
#             "yards": 2994,
#             "net_yards": 2781,
#             "blocked": 0,
#             "touchbacks": 0,
#             "inside_20": 29,
#             "return_yards": 213,
#             "avg_net_yards": 39.169,
#             "avg_yards": 42.169,
#             "longest": 56,
#             "hang_time": 320.996,
#             "avg_hang_time": 4.521
#         },
#         "punt_returns": {
#             "avg_yards": 9.538,
#             "returns": 39,
#             "yards": 372,
#             "longest": 46,
#             "touchdowns": 0,
#             "longest_touchdown": 0,
#             "faircatches": 26
#         },
#         "penalties": {
#             "penalties": 100,
#             "yards": 949
#         },
#         "passing": {
#             "attempts": 527,
#             "completions": 357,
#             "cmp_pct": 67.742,
#             "interceptions": 8,
#             "sack_yards": 176,
#             "rating": 99,
#             "touchdowns": 25,
#             "avg_yards": 7.455,
#             "sacks": 27,
#             "longest": 65,
#             "longest_touchdown": 65,
#             "air_yards": 1944,
#             "redzone_attempts": 30,
#             "net_yards": 3753,
#             "yards": 3753,
#             "gross_yards": 3929,
#             "throw_aways": 20,
#             "poor_throws": 69,
#             "defended_passes": 60,
#             "dropped_passes": 20,
#             "spikes": 0,
#             "blitzes": 175,
#             "hurries": 129,
#             "knockdowns": 49,
#             "pocket_time": 1442.075
#         },
#         "misc_returns": {
#             "yards": 40,
#             "touchdowns": 0,
#             "longest_touchdown": 0,
#             "blk_fg_touchdowns": 0,
#             "blk_punt_touchdowns": 0,
#             "fg_return_touchdowns": 0,
#             "ez_rec_touchdowns": 0,
#             "returns": 1
#         },
#         "kickoffs": {
#             "endzone": 18,
#             "inside_20": 9,
#             "return_yards": 1023,
#             "returned": 0,
#             "touchbacks": 44,
#             "yards": 5638,
#             "out_of_bounds": 0,
#             "kickoffs": 89,
#             "onside_attempts": 0,
#             "onside_successes": 0,
#             "squib_kicks": 2
#         },
#         "kick_returns": {
#             "avg_yards": 24.76,
#             "yards": 619,
#             "longest": 39,
#             "touchdowns": 0,
#             "longest_touchdown": 0,
#             "faircatches": 0,
#             "returns": 25
#         },
#         "interceptions": {
#             "return_yards": 200,
#             "returned": 14,
#             "interceptions": 14
#         },
#         "int_returns": {
#             "avg_yards": 14.286,
#             "yards": 200,
#             "longest": 36,
#             "touchdowns": 1,
#             "longest_touchdown": 31,
#             "returns": 14
#         },
#         "fumbles": {
#             "fumbles": 11,
#             "lost_fumbles": 6,
#             "own_rec": 2,
#             "own_rec_yards": 0,
#             "opp_rec": 5,
#             "opp_rec_yards": 0,
#             "out_of_bounds": 3,
#             "forced_fumbles": 8,
#             "own_rec_tds": 0,
#             "opp_rec_tds": 0,
#             "ez_rec_tds": 0
#         },
#         "first_downs": {
#             "pass": 196,
#             "penalty": 38,
#             "rush": 100,
#             "total": 334
#         },
#         "field_goals": {
#             "attempts": 38,
#             "made": 32,
#             "blocked": 1,
#             "yards": 1184,
#             "avg_yards": 32.0,
#             "longest": 53
#         },
#         "extra_points": {
#             "kicks": {
#                 "attempts": 39,
#                 "blocked": 2,
#                 "made": 34
#             },
#             "conversions": {
#                 "pass_attempts": 1,
#                 "pass_successes": 1,
#                 "rush_attempts": 1,
#                 "rush_successes": 1,
#                 "defense_attempts": 0,
#                 "defense_successes": 0,
#                 "turnover_successes": 0
#             }
#         },
#         "efficiency": {
#             "goaltogo": {
#                 "attempts": 31,
#                 "successes": 24,
#                 "pct": 77.419
#             },
#             "redzone": {
#                 "attempts": 57,
#                 "successes": 33,
#                 "pct": 57.895
#             },
#             "thirddown": {
#                 "attempts": 216,
#                 "successes": 94,
#                 "pct": 43.519
#             },
#             "fourthdown": {
#                 "attempts": 7,
#                 "successes": 1,
#                 "pct": 14.286
#             }
#         },
#         "defense": {
#             "tackles": 558,
#             "assists": 264,
#             "combined": 822,
#             "sacks": 37.0,
#             "sack_yards": 251.0,
#             "interceptions": 14,
#             "passes_defended": 71,
#             "forced_fumbles": 5,
#             "fumble_recoveries": 4,
#             "qb_hits": 84,
#             "tloss": 77.0,
#             "tloss_yards": 338.0,
#             "safeties": 1,
#             "sp_tackles": 56,
#             "sp_assists": 25,
#             "sp_forced_fumbles": 1,
#             "sp_fumble_recoveries": 2,
#             "sp_blocks": 0,
#             "misc_tackles": 14,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 2,
#             "misc_fumble_recoveries": 1,
#             "def_targets": 562,
#             "def_comps": 321,
#             "blitzes": 186,
#             "hurries": 131,
#             "knockdowns": 44,
#             "missed_tackles": 68
#         }
#     },
#     "opponents": {
#         "games_played": 16,
#         "touchdowns": {
#             "pass": 13,
#             "rush": 10,
#             "total_return": 1,
#             "total": 24,
#             "fumble_return": 0,
#             "int_return": 0,
#             "kick_return": 0,
#             "punt_return": 1,
#             "other": 0
#         },
#         "rushing": {
#             "avg_yards": 3.673,
#             "attempts": 364,
#             "touchdowns": 10,
#             "tlost": 32,
#             "tlost_yards": -70,
#             "yards": 1337,
#             "longest": 62,
#             "longest_touchdown": 60,
#             "redzone_attempts": 23,
#             "broken_tackles": 9,
#             "kneel_downs": 9,
#             "scrambles": 15,
#             "yards_after_contact": 403
#         },
#         "receiving": {
#             "targets": 551,
#             "receptions": 324,
#             "avg_yards": 10.275,
#             "yards": 3329,
#             "touchdowns": 13,
#             "yards_after_catch": 1452,
#             "longest": 52,
#             "longest_touchdown": 43,
#             "redzone_targets": 29,
#             "air_yards": 1877,
#             "broken_tackles": 18,
#             "dropped_passes": 23,
#             "catchable_passes": 33,
#             "yards_after_contact": 284
#         },
#         "punts": {
#             "attempts": 86,
#             "yards": 3892,
#             "net_yards": 3480,
#             "blocked": 0,
#             "touchbacks": 2,
#             "inside_20": 29,
#             "return_yards": 372,
#             "avg_net_yards": 40.465,
#             "avg_yards": 45.256,
#             "longest": 68,
#             "hang_time": 372.021,
#             "avg_hang_time": 4.326
#         },
#         "punt_returns": {
#             "avg_yards": 8.875,
#             "returns": 24,
#             "yards": 213,
#             "longest": 59,
#             "touchdowns": 1,
#             "longest_touchdown": 59,
#             "faircatches": 33
#         },
#         "penalties": {
#             "penalties": 105,
#             "yards": 928
#         },
#         "passing": {
#             "attempts": 555,
#             "completions": 324,
#             "cmp_pct": 58.378,
#             "interceptions": 14,
#             "sack_yards": 251,
#             "rating": 73,
#             "touchdowns": 13,
#             "avg_yards": 5.998,
#             "sacks": 37,
#             "longest": 52,
#             "longest_touchdown": 43,
#             "air_yards": 1877,
#             "redzone_attempts": 31,
#             "net_yards": 3078,
#             "yards": 3078,
#             "gross_yards": 3329,
#             "throw_aways": 20,
#             "poor_throws": 122,
#             "defended_passes": 65,
#             "dropped_passes": 23,
#             "spikes": 1,
#             "blitzes": 131,
#             "hurries": 109,
#             "knockdowns": 44,
#             "pocket_time": 1457.8509999999999
#         },
#         "kickoffs": {
#             "endzone": 17,
#             "inside_20": 10,
#             "return_yards": 619,
#             "returned": 0,
#             "touchbacks": 40,
#             "yards": 4299,
#             "out_of_bounds": 2,
#             "kickoffs": 67,
#             "onside_attempts": 2,
#             "onside_successes": 0,
#             "squib_kicks": 0
#         },
#         "kick_returns": {
#             "avg_yards": 22.733,
#             "yards": 1023,
#             "longest": 71,
#             "touchdowns": 0,
#             "longest_touchdown": 0,
#             "faircatches": 0,
#             "returns": 45
#         },
#         "interceptions": {
#             "return_yards": 97,
#             "returned": 8,
#             "interceptions": 8
#         },
#         "int_returns": {
#             "avg_yards": 12.125,
#             "yards": 97,
#             "longest": 33,
#             "touchdowns": 0,
#             "longest_touchdown": 0,
#             "returns": 8
#         },
#         "fumbles": {
#             "fumbles": 16,
#             "lost_fumbles": 5,
#             "own_rec": 9,
#             "own_rec_yards": -6,
#             "opp_rec": 6,
#             "opp_rec_yards": 72,
#             "out_of_bounds": 2,
#             "forced_fumbles": 10,
#             "own_rec_tds": 0,
#             "opp_rec_tds": 0,
#             "ez_rec_tds": 0
#         },
#         "first_downs": {
#             "pass": 168,
#             "penalty": 33,
#             "rush": 59,
#             "total": 260
#         },
#         "field_goals": {
#             "attempts": 30,
#             "made": 27,
#             "blocked": 0,
#             "yards": 1005,
#             "avg_yards": 33.5,
#             "longest": 57
#         },
#         "extra_points": {
#             "kicks": {
#                 "attempts": 22,
#                 "blocked": 0,
#                 "made": 21
#             },
#             "conversions": {
#                 "pass_attempts": 1,
#                 "pass_successes": 1,
#                 "rush_attempts": 1,
#                 "rush_successes": 1,
#                 "defense_attempts": 0,
#                 "defense_successes": 0,
#                 "turnover_successes": 0
#             }
#         },
#         "efficiency": {
#             "goaltogo": {
#                 "attempts": 18,
#                 "successes": 9,
#                 "pct": 50.0
#             },
#             "redzone": {
#                 "attempts": 40,
#                 "successes": 16,
#                 "pct": 40.0
#             },
#             "thirddown": {
#                 "attempts": 202,
#                 "successes": 51,
#                 "pct": 25.248
#             },
#             "fourthdown": {
#                 "attempts": 23,
#                 "successes": 9,
#                 "pct": 39.13
#             }
#         },
#         "defense": {
#             "tackles": 672,
#             "assists": 297,
#             "combined": 969,
#             "sacks": 27.0,
#             "sack_yards": 176.0,
#             "interceptions": 8,
#             "passes_defended": 65,
#             "forced_fumbles": 8,
#             "fumble_recoveries": 6,
#             "qb_hits": 85,
#             "tloss": 79.0,
#             "tloss_yards": 328.0,
#             "safeties": 1,
#             "sp_tackles": 56,
#             "sp_assists": 20,
#             "sp_forced_fumbles": 2,
#             "sp_fumble_recoveries": 1,
#             "sp_blocks": 3,
#             "misc_tackles": 15,
#             "misc_assists": 2,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 8,
#             "def_targets": 547,
#             "def_comps": 363,
#             "blitzes": 396,
#             "hurries": 133,
#             "knockdowns": 48,
#             "missed_tackles": 111
#         }
#     },
#     "players": [
#         {
#             "id": "016a6d56-0b72-490e-8dae-41b5d3d2db63",
#             "name": "Jaleel Johnson",
#             "jersey": "94",
#             "reference": "00-0033940",
#             "position": "DT",
#             "games_played": 5,
#             "games_started": 0,
#             "defense": {
#                 "tackles": 0,
#                 "assists": 1,
#                 "combined": 1,
#                 "sacks": 0.0,
#                 "sack_yards": 0.0,
#                 "interceptions": 0,
#                 "passes_defended": 0,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 0,
#                 "tloss": 0.0,
#                 "tloss_yards": 0.0,
#                 "safeties": 0,
#                 "sp_tackles": 0,
#                 "sp_assists": 0,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 0,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 0,
#                 "def_comps": 0,
#                 "blitzes": 0,
#                 "hurries": 0,
#                 "knockdowns": 0,
#                 "missed_tackles": 0
#             }
#         },
#         {
#             "id": "0cc4e449-185a-4b08-9f07-c907ad0c3e05",
#             "name": "Blake Bell",
#             "jersey": "81",
#             "reference": "00-0032062",
#             "position": "TE",
#             "games_played": 13,
#             "games_started": 3,
#             "receiving": {
#                 "receptions": 3,
#                 "targets": 4,
#                 "yards": 19,
#                 "avg_yards": 6.333,
#                 "longest": 12,
#                 "touchdowns": 0,
#                 "longest_touchdown": 0,
#                 "yards_after_catch": 12,
#                 "redzone_targets": 0,
#                 "air_yards": 7,
#                 "broken_tackles": 0,
#                 "dropped_passes": 0,
#                 "catchable_passes": 0,
#                 "yards_after_contact": 0
#             },
#             "defense": {
#                 "tackles": 0,
#                 "assists": 0,
#                 "combined": 0,
#                 "sacks": 0.0,
#                 "sack_yards": 0.0,
#                 "interceptions": 0,
#                 "passes_defended": 0,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 0,
#                 "tloss": 0.0,
#                 "tloss_yards": 0.0,
#                 "safeties": 0,
#                 "sp_tackles": 1,
#                 "sp_assists": 0,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 0,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 0,
#                 "def_comps": 0,
#                 "blitzes": 0,
#                 "hurries": 0,
#                 "knockdowns": 0,
#                 "missed_tackles": 0
#             },
#             "conversions": {
#                 "pass_attempts": 0,
#                 "pass_successes": 0,
#                 "rush_attempts": 0,
#                 "rush_successes": 0,
#                 "receive_attempts": 1,
#                 "receive_successes": 1,
#                 "defense_attempts": 0,
#                 "defense_successes": 0
#             }
#         },
#         {
#             "id": "1059e9dc-97df-4643-9116-883a0573d8b1",
#             "name": "Kyle Rudolph",
#             "jersey": "82R",
#             "reference": "00-0027981",
#             "position": "TE",
#             "games_played": 16,
#             "games_started": 16,
#             "receiving": {
#                 "receptions": 57,
#                 "targets": 81,
#                 "yards": 532,
#                 "avg_yards": 9.333,
#                 "longest": 34,
#                 "touchdowns": 8,
#                 "longest_touchdown": 22,
#                 "yards_after_catch": 224,
#                 "redzone_targets": 10,
#                 "air_yards": 308,
#                 "broken_tackles": 1,
#                 "dropped_passes": 3,
#                 "catchable_passes": 6,
#                 "yards_after_contact": 29
#             },
#             "penalties": {
#                 "penalties": 1,
#                 "yards": 5
#             },
#             "defense": {
#                 "tackles": 0,
#                 "assists": 0,
#                 "combined": 0,
#                 "sacks": 0.0,
#                 "sack_yards": 0.0,
#                 "interceptions": 0,
#                 "passes_defended": 0,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 0,
#                 "tloss": 0.0,
#                 "tloss_yards": 0.0,
#                 "safeties": 0,
#                 "sp_tackles": 0,
#                 "sp_assists": 0,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 3,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 0,
#                 "def_comps": 0,
#                 "blitzes": 0,
#                 "hurries": 0,
#                 "knockdowns": 0,
#                 "missed_tackles": 0
#             }
#         },
#         {
#             "id": "155ef610-f858-4ee1-b180-afd7cf337631",
#             "name": "Kyle Carter",
#             "jersey": "86",
#             "reference": "00-0032606",
#             "position": "TE",
#             "games_played": 3,
#             "games_started": 0
#         },
#         {
#             "id": "16cd3b59-18a2-40a0-9236-e222bed17044",
#             "name": "Stacy Coley",
#             "jersey": "13",
#             "reference": "00-0033968",
#             "position": "WR",
#             "games_played": 4,
#             "games_started": 0,
#             "receiving": {
#                 "receptions": 0,
#                 "targets": 1,
#                 "yards": 0,
#                 "avg_yards": 0.0,
#                 "longest": 0,
#                 "touchdowns": 0,
#                 "longest_touchdown": 0,
#                 "yards_after_catch": 0,
#                 "redzone_targets": 0,
#                 "air_yards": 0,
#                 "broken_tackles": 0,
#                 "dropped_passes": 0,
#                 "catchable_passes": 0,
#                 "yards_after_contact": 0
#             },
#             "punt_returns": {
#                 "returns": 0,
#                 "yards": 0,
#                 "avg_yards": 0.0,
#                 "touchdowns": 0,
#                 "longest": 0,
#                 "faircatches": 2,
#                 "longest_touchdown": 0
#             },
#             "kick_returns": {
#                 "returns": 1,
#                 "yards": 19,
#                 "avg_yards": 19.0,
#                 "touchdowns": 0,
#                 "longest": 19,
#                 "faircatches": 0,
#                 "longest_touchdown": 0
#             }
#         },
#         {
#             "id": "1b3d350a-478b-4542-a430-d12cc96adc22",
#             "name": "Casey Keenum",
#             "jersey": "7",
#             "reference": "00-0028986",
#             "position": "QB",
#             "games_played": 15,
#             "games_started": 14,
#             "rushing": {
#                 "avg_yards": 4.0,
#                 "attempts": 40,
#                 "touchdowns": 1,
#                 "yards": 160,
#                 "longest": 22,
#                 "longest_touchdown": 9,
#                 "redzone_attempts": 3,
#                 "tlost": 0,
#                 "tlost_yards": 0,
#                 "broken_tackles": 1,
#                 "kneel_downs": 18,
#                 "scrambles": 17,
#                 "yards_after_contact": 14
#             },
#             "penalties": {
#                 "penalties": 4,
#                 "yards": 23
#             },
#             "passing": {
#                 "attempts": 481,
#                 "completions": 325,
#                 "cmp_pct": 67.568,
#                 "yards": 3547,
#                 "avg_yards": 7.374,
#                 "sacks": 22,
#                 "sack_yards": 136,
#                 "touchdowns": 22,
#                 "longest": 65,
#                 "interceptions": 7,
#                 "rating": 98.3,
#                 "longest_touchdown": 65,
#                 "air_yards": 1717,
#                 "redzone_attempts": 26,
#                 "gross_yards": 3547,
#                 "throw_aways": 20,
#                 "poor_throws": 63,
#                 "defended_passes": 55,
#                 "dropped_passes": 18,
#                 "spikes": 0,
#                 "blitzes": 165,
#                 "hurries": 117,
#                 "knockdowns": 45,
#                 "pocket_time": 1317.5739999999996,
#                 "avg_pocket_time": 2.739,
#                 "net_yards": 3411
#             },
#             "fumbles": {
#                 "fumbles": 1,
#                 "lost_fumbles": 1,
#                 "own_rec": 0,
#                 "own_rec_yards": 0,
#                 "opp_rec": 0,
#                 "opp_rec_yards": 0,
#                 "out_of_bounds": 0,
#                 "forced_fumbles": 1,
#                 "own_rec_tds": 0,
#                 "opp_rec_tds": 0,
#                 "ez_rec_tds": 0
#             },
#             "defense": {
#                 "tackles": 0,
#                 "assists": 0,
#                 "combined": 0,
#                 "sacks": 0.0,
#                 "sack_yards": 0.0,
#                 "interceptions": 0,
#                 "passes_defended": 0,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 0,
#                 "tloss": 0.0,
#                 "tloss_yards": 0.0,
#                 "safeties": 0,
#                 "sp_tackles": 0,
#                 "sp_assists": 0,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 1,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 1,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 0,
#                 "def_comps": 0,
#                 "blitzes": 0,
#                 "hurries": 0,
#                 "knockdowns": 0,
#                 "missed_tackles": 0
#             },
#             "conversions": {
#                 "pass_attempts": 1,
#                 "pass_successes": 1,
#                 "rush_attempts": 0,
#                 "rush_successes": 0,
#                 "receive_attempts": 0,
#                 "receive_successes": 0,
#                 "defense_attempts": 0,
#                 "defense_successes": 0
#             }
#         },
#         {
#             "id": "1cf282eb-ab14-4d2d-8a0d-702ddd83cfcc",
#             "name": "Benjamin Gedeon",
#             "jersey": "42",
#             "reference": "00-0033944",
#             "position": "OLB",
#             "games_played": 16,
#             "games_started": 9,
#             "penalties": {
#                 "penalties": 2,
#                 "yards": 20
#             },
#             "defense": {
#                 "tackles": 15,
#                 "assists": 10,
#                 "combined": 25,
#                 "sacks": 0.0,
#                 "sack_yards": 0.0,
#                 "interceptions": 0,
#                 "passes_defended": 0,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 0,
#                 "tloss": 0.0,
#                 "tloss_yards": 0.0,
#                 "safeties": 0,
#                 "sp_tackles": 8,
#                 "sp_assists": 4,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 0,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 6,
#                 "def_comps": 5,
#                 "blitzes": 2,
#                 "hurries": 0,
#                 "knockdowns": 0,
#                 "missed_tackles": 2
#             }
#         },
#         {
#             "id": "23616a22-8266-4b0c-b0b9-5f8187178168",
#             "name": "Anthony Barr",
#             "jersey": "55B",
#             "reference": "00-0031256",
#             "position": "OLB",
#             "games_played": 16,
#             "games_started": 16,
#             "penalties": {
#                 "penalties": 3,
#                 "yards": 45
#             },
#             "defense": {
#                 "tackles": 52,
#                 "assists": 23,
#                 "combined": 75,
#                 "sacks": 1.0,
#                 "sack_yards": 11.0,
#                 "interceptions": 0,
#                 "passes_defended": 6,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 4,
#                 "tloss": 9.0,
#                 "tloss_yards": 33.0,
#                 "safeties": 0,
#                 "sp_tackles": 0,
#                 "sp_assists": 0,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 0,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 70,
#                 "def_comps": 49,
#                 "blitzes": 78,
#                 "hurries": 7,
#                 "knockdowns": 4,
#                 "missed_tackles": 7
#             }
#         },
#         {
#             "id": "2a027210-21b3-4723-868d-df995e5d7441",
#             "name": "Antone Exum",
#             "jersey": "40",
#             "reference": "00-0031267",
#             "position": "FS",
#             "games_played": 0,
#             "games_started": 0
#         },
#         {
#             "id": "2e0badcd-b78c-40ee-a83b-a1bbb36bc545",
#             "name": "Laquon Treadwell",
#             "jersey": "11",
#             "reference": "00-0032951",
#             "position": "WR",
#             "games_played": 16,
#             "games_started": 7,
#             "receiving": {
#                 "receptions": 20,
#                 "targets": 35,
#                 "yards": 200,
#                 "avg_yards": 10.0,
#                 "longest": 25,
#                 "touchdowns": 0,
#                 "longest_touchdown": 0,
#                 "yards_after_catch": 58,
#                 "redzone_targets": 1,
#                 "air_yards": 142,
#                 "broken_tackles": 0,
#                 "dropped_passes": 1,
#                 "catchable_passes": 1,
#                 "yards_after_contact": 6
#             },
#             "penalties": {
#                 "penalties": 4,
#                 "yards": 40
#             },
#             "fumbles": {
#                 "fumbles": 1,
#                 "lost_fumbles": 0,
#                 "own_rec": 0,
#                 "own_rec_yards": 0,
#                 "opp_rec": 0,
#                 "opp_rec_yards": 0,
#                 "out_of_bounds": 1,
#                 "forced_fumbles": 1,
#                 "own_rec_tds": 0,
#                 "opp_rec_tds": 0,
#                 "ez_rec_tds": 0
#             },
#             "defense": {
#                 "tackles": 0,
#                 "assists": 0,
#                 "combined": 0,
#                 "sacks": 0.0,
#                 "sack_yards": 0.0,
#                 "interceptions": 0,
#                 "passes_defended": 0,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 0,
#                 "tloss": 0.0,
#                 "tloss_yards": 0.0,
#                 "safeties": 0,
#                 "sp_tackles": 0,
#                 "sp_assists": 0,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 2,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 1,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 0,
#                 "def_comps": 0,
#                 "blitzes": 0,
#                 "hurries": 0,
#                 "knockdowns": 0,
#                 "missed_tackles": 0
#             }
#         },
#         {
#             "id": "2fa2b2da-4aa9-44b5-b27e-56876dfe2ad4",
#             "name": "Adam Thielen",
#             "jersey": "19",
#             "reference": "00-0030035",
#             "position": "WR",
#             "games_played": 16,
#             "games_started": 16,
#             "rushing": {
#                 "avg_yards": 11.0,
#                 "attempts": 1,
#                 "touchdowns": 0,
#                 "yards": 11,
#                 "longest": 11,
#                 "longest_touchdown": 0,
#                 "redzone_attempts": 0,
#                 "tlost": 0,
#                 "tlost_yards": 0,
#                 "broken_tackles": 0,
#                 "kneel_downs": 0,
#                 "scrambles": 0,
#                 "yards_after_contact": 4
#             },
#             "receiving": {
#                 "receptions": 91,
#                 "targets": 142,
#                 "yards": 1276,
#                 "avg_yards": 14.022,
#                 "longest": 65,
#                 "touchdowns": 4,
#                 "longest_touchdown": 65,
#                 "yards_after_catch": 453,
#                 "redzone_targets": 7,
#                 "air_yards": 823,
#                 "broken_tackles": 0,
#                 "dropped_passes": 6,
#                 "catchable_passes": 9,
#                 "yards_after_contact": 62
#             },
#             "penalties": {
#                 "penalties": 4,
#                 "yards": 40
#             },
#             "fumbles": {
#                 "fumbles": 3,
#                 "lost_fumbles": 2,
#                 "own_rec": 0,
#                 "own_rec_yards": 0,
#                 "opp_rec": 0,
#                 "opp_rec_yards": 0,
#                 "out_of_bounds": 1,
#                 "forced_fumbles": 0,
#                 "own_rec_tds": 0,
#                 "opp_rec_tds": 0,
#                 "ez_rec_tds": 0
#             },
#             "defense": {
#                 "tackles": 0,
#                 "assists": 0,
#                 "combined": 0,
#                 "sacks": 0.0,
#                 "sack_yards": 0.0,
#                 "interceptions": 0,
#                 "passes_defended": 0,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 0,
#                 "tloss": 0.0,
#                 "tloss_yards": 0.0,
#                 "safeties": 0,
#                 "sp_tackles": 0,
#                 "sp_assists": 0,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 1,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 0,
#                 "def_comps": 0,
#                 "blitzes": 0,
#                 "hurries": 0,
#                 "knockdowns": 0,
#                 "missed_tackles": 0
#             }
#         },
#         {
#             "id": "338adc8a-173d-4b1b-a5de-92818bf96823",
#             "name": "Trae Waynes",
#             "jersey": "26",
#             "reference": "00-0031546",
#             "position": "CB",
#             "games_played": 16,
#             "games_started": 16,
#             "penalties": {
#                 "penalties": 2,
#                 "yards": 54
#             },
#             "int_returns": {
#                 "returns": 2,
#                 "yards": 21,
#                 "avg_yards": 10.5,
#                 "touchdowns": 0,
#                 "longest": 18,
#                 "longest_touchdown": 0
#             },
#             "defense": {
#                 "tackles": 57,
#                 "assists": 8,
#                 "combined": 65,
#                 "sacks": 1.0,
#                 "sack_yards": 4.0,
#                 "interceptions": 2,
#                 "passes_defended": 11,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 1,
#                 "tloss": 4.0,
#                 "tloss_yards": 11.0,
#                 "safeties": 0,
#                 "sp_tackles": 0,
#                 "sp_assists": 0,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 0,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 117,
#                 "def_comps": 66,
#                 "blitzes": 1,
#                 "hurries": 0,
#                 "knockdowns": 0,
#                 "missed_tackles": 9
#             }
#         },
#         {
#             "id": "39ee3bee-1177-49cd-a78b-7a790ffd0b84",
#             "name": "Andrew Sendejo",
#             "jersey": "34",
#             "reference": "00-0027914",
#             "position": "SS",
#             "games_played": 13,
#             "games_started": 13,
#             "penalties": {
#                 "penalties": 1,
#                 "yards": 18
#             },
#             "int_returns": {
#                 "returns": 2,
#                 "yards": 70,
#                 "avg_yards": 35.0,
#                 "touchdowns": 0,
#                 "longest": 36,
#                 "longest_touchdown": 0
#             },
#             "defense": {
#                 "tackles": 52,
#                 "assists": 25,
#                 "combined": 77,
#                 "sacks": 0.0,
#                 "sack_yards": 0.0,
#                 "interceptions": 2,
#                 "passes_defended": 7,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 0,
#                 "tloss": 1.0,
#                 "tloss_yards": 2.0,
#                 "safeties": 0,
#                 "sp_tackles": 2,
#                 "sp_assists": 1,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 0,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 36,
#                 "def_comps": 16,
#                 "blitzes": 5,
#                 "hurries": 0,
#                 "knockdowns": 0,
#                 "missed_tackles": 9
#             }
#         },
#         {
#             "id": "3f6b7426-8fc2-44c8-9cba-9d6234e9d43d",
#             "name": "Emmanuel Lamur",
#             "jersey": "59",
#             "reference": "00-0029479",
#             "position": "OLB",
#             "games_played": 16,
#             "games_started": 0,
#             "penalties": {
#                 "penalties": 1,
#                 "yards": 5
#             },
#             "fumbles": {
#                 "fumbles": 0,
#                 "lost_fumbles": 0,
#                 "own_rec": 0,
#                 "own_rec_yards": 0,
#                 "opp_rec": 1,
#                 "opp_rec_yards": 0,
#                 "out_of_bounds": 0,
#                 "forced_fumbles": 0,
#                 "own_rec_tds": 0,
#                 "opp_rec_tds": 0,
#                 "ez_rec_tds": 0
#             },
#             "defense": {
#                 "tackles": 8,
#                 "assists": 6,
#                 "combined": 14,
#                 "sacks": 0.0,
#                 "sack_yards": 0.0,
#                 "interceptions": 0,
#                 "passes_defended": 1,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 0,
#                 "tloss": 0.0,
#                 "tloss_yards": 0.0,
#                 "safeties": 0,
#                 "sp_tackles": 1,
#                 "sp_assists": 2,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 1,
#                 "sp_blocks": 0,
#                 "misc_tackles": 0,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 6,
#                 "def_comps": 4,
#                 "blitzes": 1,
#                 "hurries": 0,
#                 "knockdowns": 0,
#                 "missed_tackles": 0
#             }
#         },
#         {
#             "id": "407f1923-6659-4564-800f-25b8746d6d3e",
#             "name": "Harrison Smith",
#             "jersey": "22S",
#             "reference": "00-0029606",
#             "position": "FS",
#             "games_played": 16,
#             "games_started": 16,
#             "penalties": {
#                 "penalties": 1,
#                 "yards": 5
#             },
#             "int_returns": {
#                 "returns": 5,
#                 "yards": 42,
#                 "avg_yards": 8.4,
#                 "touchdowns": 0,
#                 "longest": 19,
#                 "longest_touchdown": 0
#             },
#             "defense": {
#                 "tackles": 61,
#                 "assists": 17,
#                 "combined": 78,
#                 "sacks": 1.5,
#                 "sack_yards": 10.0,
#                 "interceptions": 5,
#                 "passes_defended": 12,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 3,
#                 "tloss": 7.0,
#                 "tloss_yards": 24.0,
#                 "safeties": 0,
#                 "sp_tackles": 0,
#                 "sp_assists": 0,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 0,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 55,
#                 "def_comps": 27,
#                 "blitzes": 24,
#                 "hurries": 5,
#                 "knockdowns": 0,
#                 "missed_tackles": 5
#             }
#         },
#         {
#             "id": "471dbe81-54c4-4b52-8bd1-4933c9800e1f",
#             "name": "Michael Floyd",
#             "jersey": "18",
#             "reference": "00-0029638",
#             "position": "WR",
#             "games_played": 11,
#             "games_started": 1,
#             "receiving": {
#                 "receptions": 10,
#                 "targets": 17,
#                 "yards": 78,
#                 "avg_yards": 7.8,
#                 "longest": 19,
#                 "touchdowns": 0,
#                 "longest_touchdown": 0,
#                 "yards_after_catch": 34,
#                 "redzone_targets": 0,
#                 "air_yards": 44,
#                 "broken_tackles": 0,
#                 "dropped_passes": 1,
#                 "catchable_passes": 1,
#                 "yards_after_contact": 0
#             },
#             "penalties": {
#                 "penalties": 1,
#                 "yards": 10
#             }
#         },
#         {
#             "id": "49606a1d-e06e-4cde-8528-f1adca8bd5fa",
#             "name": "Cornelius Edison",
#             "jersey": "67",
#             "reference": "00-0032324",
#             "position": "C",
#             "games_played": 0,
#             "games_started": 0
#         },
#         {
#             "id": "4a69f085-8bef-4b3c-a66e-cab65b3fcb7a",
#             "name": "Terence Newman",
#             "jersey": "23",
#             "reference": "00-0022045",
#             "position": "CB",
#             "games_played": 16,
#             "games_started": 7,
#             "penalties": {
#                 "penalties": 1,
#                 "yards": 5
#             },
#             "int_returns": {
#                 "returns": 1,
#                 "yards": 3,
#                 "avg_yards": 3.0,
#                 "touchdowns": 0,
#                 "longest": 3,
#                 "longest_touchdown": 0
#             },
#             "defense": {
#                 "tackles": 25,
#                 "assists": 10,
#                 "combined": 35,
#                 "sacks": 0.0,
#                 "sack_yards": 0.0,
#                 "interceptions": 1,
#                 "passes_defended": 5,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 0,
#                 "tloss": 2.0,
#                 "tloss_yards": 2.0,
#                 "safeties": 0,
#                 "sp_tackles": 0,
#                 "sp_assists": 0,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 0,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 48,
#                 "def_comps": 25,
#                 "blitzes": 10,
#                 "hurries": 0,
#                 "knockdowns": 0,
#                 "missed_tackles": 3
#             }
#         },
#         {
#             "id": "4a9a26fa-6a05-4c67-a023-43773a5c67f8",
#             "name": "Jeremiah Sirles",
#             "jersey": "75",
#             "reference": "00-0030923",
#             "position": "G",
#             "games_played": 14,
#             "games_started": 4,
#             "penalties": {
#                 "penalties": 3,
#                 "yards": 20
#             }
#         },
#         {
#             "id": "4bff1c89-f4d1-4699-8c85-69bbbbaec5a2",
#             "name": "David Morgan",
#             "jersey": "89",
#             "reference": "00-0032430",
#             "position": "TE",
#             "games_played": 15,
#             "games_started": 6,
#             "receiving": {
#                 "receptions": 10,
#                 "targets": 12,
#                 "yards": 95,
#                 "avg_yards": 9.5,
#                 "longest": 23,
#                 "touchdowns": 1,
#                 "longest_touchdown": 1,
#                 "yards_after_catch": 57,
#                 "redzone_targets": 0,
#                 "air_yards": 38,
#                 "broken_tackles": 1,
#                 "dropped_passes": 0,
#                 "catchable_passes": 0,
#                 "yards_after_contact": 23
#             },
#             "penalties": {
#                 "penalties": 3,
#                 "yards": 30
#             },
#             "fumbles": {
#                 "fumbles": 0,
#                 "lost_fumbles": 0,
#                 "own_rec": 1,
#                 "own_rec_yards": 0,
#                 "opp_rec": 0,
#                 "opp_rec_yards": 0,
#                 "out_of_bounds": 0,
#                 "forced_fumbles": 0,
#                 "own_rec_tds": 0,
#                 "opp_rec_tds": 0,
#                 "ez_rec_tds": 0
#             },
#             "defense": {
#                 "tackles": 0,
#                 "assists": 0,
#                 "combined": 0,
#                 "sacks": 0.0,
#                 "sack_yards": 0.0,
#                 "interceptions": 0,
#                 "passes_defended": 0,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 0,
#                 "tloss": 0.0,
#                 "tloss_yards": 0.0,
#                 "safeties": 0,
#                 "sp_tackles": 0,
#                 "sp_assists": 0,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 1,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 1,
#                 "def_targets": 0,
#                 "def_comps": 0,
#                 "blitzes": 0,
#                 "hurries": 0,
#                 "knockdowns": 0,
#                 "missed_tackles": 0
#             }
#         },
#         {
#             "id": "4f799675-2b27-4437-9acc-bc4e0c73ef0f",
#             "name": "Marcus Sherels",
#             "jersey": "35",
#             "reference": "00-0027547",
#             "position": "CB",
#             "games_played": 16,
#             "games_started": 0,
#             "punt_returns": {
#                 "returns": 39,
#                 "yards": 372,
#                 "avg_yards": 9.538,
#                 "touchdowns": 0,
#                 "longest": 46,
#                 "faircatches": 24,
#                 "longest_touchdown": 0
#             },
#             "misc_returns": {
#                 "returns": 1,
#                 "yards": 40,
#                 "touchdowns": 0,
#                 "longest_touchdown": 0,
#                 "blk_fg_touchdowns": 0,
#                 "blk_punt_touchdowns": 0,
#                 "fg_return_touchdowns": 0,
#                 "ez_rec_touchdowns": 0
#             },
#             "kick_returns": {
#                 "returns": 11,
#                 "yards": 271,
#                 "avg_yards": 24.636,
#                 "touchdowns": 0,
#                 "longest": 32,
#                 "faircatches": 0,
#                 "longest_touchdown": 0
#             },
#             "fumbles": {
#                 "fumbles": 1,
#                 "lost_fumbles": 0,
#                 "own_rec": 1,
#                 "own_rec_yards": 0,
#                 "opp_rec": 0,
#                 "opp_rec_yards": 0,
#                 "out_of_bounds": 0,
#                 "forced_fumbles": 0,
#                 "own_rec_tds": 0,
#                 "opp_rec_tds": 0,
#                 "ez_rec_tds": 0
#             },
#             "defense": {
#                 "tackles": 1,
#                 "assists": 0,
#                 "combined": 1,
#                 "sacks": 0.0,
#                 "sack_yards": 0.0,
#                 "interceptions": 0,
#                 "passes_defended": 0,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 0,
#                 "tloss": 0.0,
#                 "tloss_yards": 0.0,
#                 "safeties": 0,
#                 "sp_tackles": 5,
#                 "sp_assists": 0,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 1,
#                 "sp_blocks": 0,
#                 "misc_tackles": 0,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 3,
#                 "def_comps": 2,
#                 "blitzes": 0,
#                 "hurries": 0,
#                 "knockdowns": 0,
#                 "missed_tackles": 0
#             }
#         },
#         {
#             "id": "540f8b30-900e-4d17-8756-c262ba5fa039",
#             "name": "Latavius Murray",
#             "jersey": "25",
#             "reference": "00-0030513",
#             "position": "RB",
#             "games_played": 16,
#             "games_started": 11,
#             "rushing": {
#                 "avg_yards": 3.898,
#                 "attempts": 216,
#                 "touchdowns": 8,
#                 "yards": 842,
#                 "longest": 46,
#                 "longest_touchdown": 29,
#                 "redzone_attempts": 13,
#                 "tlost": 24,
#                 "tlost_yards": -50,
#                 "broken_tackles": 10,
#                 "kneel_downs": 0,
#                 "scrambles": 0,
#                 "yards_after_contact": 294
#             },
#             "receiving": {
#                 "receptions": 15,
#                 "targets": 17,
#                 "yards": 103,
# ...
#                 "out_of_bounds": 0,
#                 "onside_attempts": 0,
#                 "onside_successes": 0,
#                 "squib_kicks": 0
#             }
#         },
#         {
#             "id": "ba7fe857-df63-4aed-803a-80993b157be4",
#             "name": "Danielle Hunter",
#             "jersey": "99",
#             "reference": "00-0031565",
#             "position": "DE",
#             "games_played": 16,
#             "games_started": 16,
#             "penalties": {
#                 "penalties": 1,
#                 "yards": 2
#             },
#             "fumbles": {
#                 "fumbles": 0,
#                 "lost_fumbles": 0,
#                 "own_rec": 0,
#                 "own_rec_yards": 0,
#                 "opp_rec": 1,
#                 "opp_rec_yards": 0,
#                 "out_of_bounds": 0,
#                 "forced_fumbles": 1,
#                 "own_rec_tds": 0,
#                 "opp_rec_tds": 0,
#                 "ez_rec_tds": 0
#             },
#             "defense": {
#                 "tackles": 27,
#                 "assists": 18,
#                 "combined": 45,
#                 "sacks": 7.0,
#                 "sack_yards": 56.0,
#                 "interceptions": 0,
#                 "passes_defended": 2,
#                 "forced_fumbles": 1,
#                 "fumble_recoveries": 1,
#                 "qb_hits": 11,
#                 "tloss": 12.0,
#                 "tloss_yards": 69.0,
#                 "safeties": 0,
#                 "sp_tackles": 0,
#                 "sp_assists": 0,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 0,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 3,
#                 "def_comps": 2,
#                 "blitzes": 0,
#                 "hurries": 39,
#                 "knockdowns": 4,
#                 "missed_tackles": 4
#             }
#         },
#         {
#             "id": "bfe704fc-266d-4f6a-afbf-c903b5934e23",
#             "name": "Eric Wilson",
#             "jersey": "50",
#             "reference": "00-0033336",
#             "position": "OLB",
#             "games_played": 16,
#             "games_started": 0,
#             "penalties": {
#                 "penalties": 1,
#                 "yards": 15
#             },
#             "fumbles": {
#                 "fumbles": 0,
#                 "lost_fumbles": 0,
#                 "own_rec": 0,
#                 "own_rec_yards": 0,
#                 "opp_rec": 0,
#                 "opp_rec_yards": 0,
#                 "out_of_bounds": 0,
#                 "forced_fumbles": 1,
#                 "own_rec_tds": 0,
#                 "opp_rec_tds": 0,
#                 "ez_rec_tds": 0
#             },
#             "defense": {
#                 "tackles": 0,
#                 "assists": 0,
#                 "combined": 0,
#                 "sacks": 0.0,
#                 "sack_yards": 0.0,
#                 "interceptions": 0,
#                 "passes_defended": 0,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 0,
#                 "tloss": 0.0,
#                 "tloss_yards": 0.0,
#                 "safeties": 0,
#                 "sp_tackles": 5,
#                 "sp_assists": 3,
#                 "sp_forced_fumbles": 1,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 0,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 0,
#                 "def_comps": 0,
#                 "blitzes": 0,
#                 "hurries": 0,
#                 "knockdowns": 0,
#                 "missed_tackles": 0
#             }
#         },
#         {
#             "id": "cc3640b0-7560-431f-84ab-599e9dc8cac6",
#             "name": "Samuel Bradford",
#             "jersey": "8",
#             "reference": "00-0027854",
#             "position": "QB",
#             "games_played": 2,
#             "games_started": 2,
#             "rushing": {
#                 "avg_yards": -1.5,
#                 "attempts": 2,
#                 "touchdowns": 0,
#                 "yards": -3,
#                 "longest": -1,
#                 "longest_touchdown": 0,
#                 "redzone_attempts": 0,
#                 "tlost": 0,
#                 "tlost_yards": 0,
#                 "broken_tackles": 0,
#                 "kneel_downs": 0,
#                 "scrambles": 0,
#                 "yards_after_contact": 0
#             },
#             "passing": {
#                 "attempts": 43,
#                 "completions": 32,
#                 "cmp_pct": 74.419,
#                 "yards": 382,
#                 "avg_yards": 8.884,
#                 "sacks": 5,
#                 "sack_yards": 40,
#                 "touchdowns": 3,
#                 "longest": 44,
#                 "interceptions": 0,
#                 "rating": 124.4,
#                 "longest_touchdown": 18,
#                 "air_yards": 227,
#                 "redzone_attempts": 4,
#                 "gross_yards": 382,
#                 "throw_aways": 0,
#                 "poor_throws": 6,
#                 "defended_passes": 4,
#                 "dropped_passes": 1,
#                 "spikes": 0,
#                 "blitzes": 10,
#                 "hurries": 11,
#                 "knockdowns": 4,
#                 "pocket_time": 118.36999999999999,
#                 "avg_pocket_time": 2.753,
#                 "net_yards": 342
#             }
#         },
#         {
#             "id": "d38bd9b4-1927-4cca-84da-5c7dd5b21716",
#             "name": "Tashawn Bower",
#             "jersey": "90",
#             "reference": "00-0033324",
#             "position": "DE",
#             "games_played": 2,
#             "games_started": 0,
#             "defense": {
#                 "tackles": 1,
#                 "assists": 0,
#                 "combined": 1,
#                 "sacks": 1.0,
#                 "sack_yards": 7.0,
#                 "interceptions": 0,
#                 "passes_defended": 0,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 1,
#                 "tloss": 1.0,
#                 "tloss_yards": 7.0,
#                 "safeties": 0,
#                 "sp_tackles": 0,
#                 "sp_assists": 0,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 0,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 0,
#                 "def_comps": 0,
#                 "blitzes": 0,
#                 "hurries": 0,
#                 "knockdowns": 0,
#                 "missed_tackles": 0
#             }
#         },
#         {
#             "id": "d4cb52a9-f6b4-42ed-b40b-27bff5f1eea7",
#             "name": "Theodore Bridgewater",
#             "jersey": "5",
#             "reference": "00-0031237",
#             "position": "QB",
#             "games_played": 1,
#             "games_started": 0,
#             "rushing": {
#                 "avg_yards": -1.0,
#                 "attempts": 3,
#                 "touchdowns": 0,
#                 "yards": -3,
#                 "longest": -1,
#                 "longest_touchdown": 0,
#                 "redzone_attempts": 0,
#                 "tlost": 0,
#                 "tlost_yards": 0,
#                 "broken_tackles": 0,
#                 "kneel_downs": 3,
#                 "scrambles": 0,
#                 "yards_after_contact": 0
#             },
#             "passing": {
#                 "attempts": 2,
#                 "completions": 0,
#                 "cmp_pct": 0.0,
#                 "yards": 0,
#                 "avg_yards": 0.0,
#                 "sacks": 0,
#                 "sack_yards": 0,
#                 "touchdowns": 0,
#                 "longest": 0,
#                 "interceptions": 1,
#                 "rating": 0.0,
#                 "longest_touchdown": 0,
#                 "air_yards": 0,
#                 "redzone_attempts": 0,
#                 "gross_yards": 0,
#                 "throw_aways": 0,
#                 "poor_throws": 0,
#                 "defended_passes": 1,
#                 "dropped_passes": 1,
#                 "spikes": 0,
#                 "blitzes": 0,
#                 "hurries": 1,
#                 "knockdowns": 0,
#                 "pocket_time": 6.131,
#                 "avg_pocket_time": 3.066,
#                 "net_yards": 0
#             }
#         },
#         {
#             "id": "dc8a06c8-538a-4408-8a2b-1d9bfafb8a3c",
#             "name": "Rodney Adams",
#             "jersey": "12",
#             "reference": "00-0033957",
#             "position": "WR",
#             "games_played": 0,
#             "games_started": 0
#         },
#         {
#             "id": "e1b3b636-39b5-46cf-aa7f-216b09ead7e6",
#             "name": "Shamar Stephen",
#             "jersey": "93",
#             "reference": "00-0031242",
#             "position": "NT",
#             "games_played": 15,
#             "games_started": 1,
#             "penalties": {
#                 "penalties": 2,
#                 "yards": 20
#             },
#             "defense": {
#                 "tackles": 9,
#                 "assists": 19,
#                 "combined": 28,
#                 "sacks": 1.0,
#                 "sack_yards": 9.0,
#                 "interceptions": 0,
#                 "passes_defended": 0,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 3,
#                 "tloss": 1.0,
#                 "tloss_yards": 9.0,
#                 "safeties": 0,
#                 "sp_tackles": 0,
#                 "sp_assists": 0,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 0,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 1,
#                 "def_comps": 0,
#                 "blitzes": 0,
#                 "hurries": 4,
#                 "knockdowns": 2,
#                 "missed_tackles": 0
#             }
#         },
#         {
#             "id": "e23505d9-b677-4a86-ba17-564c165a6e66",
#             "name": "Kyle Sloter",
#             "jersey": "1",
#             "reference": "00-0033672",
#             "position": "QB",
#             "games_played": 0,
#             "games_started": 0
#         },
#         {
#             "id": "e805571c-fc68-438c-b8db-2d1286d99182",
#             "name": "Daniel Isidora",
#             "jersey": "63",
#             "reference": "00-0033960",
#             "position": "G",
#             "games_played": 7,
#             "games_started": 1,
#             "penalties": {
#                 "penalties": 1,
#                 "yards": 13
#             }
#         },
#         {
#             "id": "ee305db3-cdaf-4eb3-b950-7146d51eac34",
#             "name": "Tom Johnson",
#             "jersey": "92",
#             "reference": "00-0024030",
#             "position": "DT",
#             "games_played": 16,
#             "games_started": 15,
#             "penalties": {
#                 "penalties": 5,
#                 "yards": 44
#             },
#             "defense": {
#                 "tackles": 17,
#                 "assists": 15,
#                 "combined": 32,
#                 "sacks": 2.0,
#                 "sack_yards": 8.0,
#                 "interceptions": 0,
#                 "passes_defended": 0,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 10,
#                 "tloss": 5.0,
#                 "tloss_yards": 15.0,
#                 "safeties": 0,
#                 "sp_tackles": 0,
#                 "sp_assists": 0,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 0,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 0,
#                 "def_comps": 0,
#                 "blitzes": 0,
#                 "hurries": 15,
#                 "knockdowns": 6,
#                 "missed_tackles": 2
#             }
#         },
#         {
#             "id": "f77479d7-51a5-41f9-8924-69526dd078cd",
#             "name": "Jerick McKinnon",
#             "jersey": "21",
#             "reference": "00-0031376",
#             "position": "RB",
#             "games_played": 16,
#             "games_started": 1,
#             "rushing": {
#                 "avg_yards": 3.8,
#                 "attempts": 150,
#                 "touchdowns": 3,
#                 "yards": 570,
#                 "longest": 58,
#                 "longest_touchdown": 58,
#                 "redzone_attempts": 5,
#                 "tlost": 23,
#                 "tlost_yards": -59,
#                 "broken_tackles": 14,
#                 "kneel_downs": 0,
#                 "scrambles": 0,
#                 "yards_after_contact": 237
#             },
#             "receiving": {
#                 "receptions": 51,
#                 "targets": 68,
#                 "yards": 421,
#                 "avg_yards": 8.255,
#                 "longest": 41,
#                 "touchdowns": 2,
#                 "longest_touchdown": 27,
#                 "yards_after_catch": 450,
#                 "redzone_targets": 1,
#                 "air_yards": -29,
#                 "broken_tackles": 3,
#                 "dropped_passes": 2,
#                 "catchable_passes": 2,
#                 "yards_after_contact": 64
#             },
#             "kick_returns": {
#                 "returns": 12,
#                 "yards": 312,
#                 "avg_yards": 26.0,
#                 "touchdowns": 0,
#                 "longest": 39,
#                 "faircatches": 0,
#                 "longest_touchdown": 0
#             },
#             "fumbles": {
#                 "fumbles": 3,
#                 "lost_fumbles": 2,
#                 "own_rec": 0,
#                 "own_rec_yards": 0,
#                 "opp_rec": 0,
#                 "opp_rec_yards": 0,
#                 "out_of_bounds": 1,
#                 "forced_fumbles": 0,
#                 "own_rec_tds": 0,
#                 "opp_rec_tds": 0,
#                 "ez_rec_tds": 0
#             },
#             "defense": {
#                 "tackles": 0,
#                 "assists": 0,
#                 "combined": 0,
#                 "sacks": 0.0,
#                 "sack_yards": 0.0,
#                 "interceptions": 0,
#                 "passes_defended": 0,
#                 "forced_fumbles": 0,
#                 "fumble_recoveries": 0,
#                 "qb_hits": 0,
#                 "tloss": 0.0,
#                 "tloss_yards": 0.0,
#                 "safeties": 0,
#                 "sp_tackles": 0,
#                 "sp_assists": 1,
#                 "sp_forced_fumbles": 0,
#                 "sp_fumble_recoveries": 0,
#                 "sp_blocks": 0,
#                 "misc_tackles": 1,
#                 "misc_assists": 0,
#                 "misc_forced_fumbles": 0,
#                 "misc_fumble_recoveries": 0,
#                 "def_targets": 0,
#                 "def_comps": 0,
#                 "blitzes": 0,
#                 "hurries": 0,
#                 "knockdowns": 0,
#                 "missed_tackles": 0
#             },
#             "conversions": {
#                 "pass_attempts": 0,
#                 "pass_successes": 0,
#                 "rush_attempts": 1,
#                 "rush_successes": 1,
#                 "receive_attempts": 0,
#                 "receive_successes": 0,
#                 "defense_attempts": 0,
#                 "defense_successes": 0
#             }
#         },
#         {
#             "id": "f9d87dfe-4a57-482a-a77f-37906daa4382",
#             "name": "Patrick Elflein",
#             "jersey": "65",
#             "reference": "00-0033909",
#             "position": "C",
#             "games_played": 14,
#             "games_started": 14,
#             "penalties": {
#                 "penalties": 1,
#                 "yards": 5
#             }
#         }
#     ],
#     "_comment": "Generation started @ 2018-02-02 00:17:00 +0000 ended @ 2018-02-02 00:17:00 +0000"
# }

# %% [markdown]
# # Team ID List

# %%
team_id_url = "http://api.sportradar.us/nfl-ot2/league/hierarchy.json?api_key="

team_id_response = requests.get(team_id_url + o_key)
team_id_json = team_id_response.json()

print(json.dumps(team_id_json, indent=4))
# Out:
# {
#     "league": {
#         "id": "3c6d318a-6164-4290-9bbc-bf9bb21cc4b8",
#         "name": "National Football League",
#         "alias": "NFL"
#     },
#     "conferences": [
#         {
#             "id": "1bdefe12-6cb2-4d6a-b208-b04602ae79c3",
#             "name": "AFC",
#             "alias": "AFC",
#             "divisions": [
#                 {
#                     "id": "b95cd27d-d631-4fe1-bc05-0ae47fc0b14b",
#                     "name": "AFC East",
#                     "alias": "AFC_EAST",
#                     "teams": [
#                         {
#                             "id": "768c92aa-75ff-4a43-bcc0-f2798c2e1724",
#                             "name": "Bills",
#                             "market": "Buffalo",
#                             "alias": "BUF",
#                             "references": [
#                                 {
#                                     "id": "BUF",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "e9e0828e-37fc-4238-a317-49037577dd55",
#                                 "name": "New Era Field",
#                                 "city": "Orchard Park",
#                                 "state": "NY",
#                                 "country": "USA",
#                                 "zip": "14127",
#                                 "address": "One Bills Drive",
#                                 "capacity": 73079,
#                                 "surface": "artificial",
#                                 "roof_type": "outdoor"
#                             }
#                         },
#                         {
#                             "id": "4809ecb0-abd3-451d-9c4a-92a90b83ca06",
#                             "name": "Dolphins",
#                             "market": "Miami",
#                             "alias": "MIA",
#                             "references": [
#                                 {
#                                     "id": "MIA",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "50a5c833-1570-4c38-abc7-7914cf87dbde",
#                                 "name": "Hard Rock Stadium",
#                                 "city": "Miami Gardens",
#                                 "state": "FL",
#                                 "country": "USA",
#                                 "zip": "33056",
#                                 "address": "2269 Northwest 199th Street",
#                                 "capacity": 76100,
#                                 "surface": "turf",
#                                 "roof_type": "outdoor"
#                             }
#                         },
#                         {
#                             "id": "5fee86ae-74ab-4bdd-8416-42a9dd9964f3",
#                             "name": "Jets",
#                             "market": "New York",
#                             "alias": "NYJ",
#                             "references": [
#                                 {
#                                     "id": "NYJ",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "5d4c85c7-d84e-4e10-bd6a-8a15ebecca5c",
#                                 "name": "MetLife Stadium",
#                                 "city": "East Rutherford",
#                                 "state": "NJ",
#                                 "country": "USA",
#                                 "zip": "07073",
#                                 "address": "One MetLife Stadium Drive",
#                                 "capacity": 82500,
#                                 "surface": "artificial",
#                                 "roof_type": "outdoor"
#                             }
#                         },
#                         {
#                             "id": "97354895-8c77-4fd4-a860-32e62ea7382a",
#                             "name": "Patriots",
#                             "market": "New England",
#                             "alias": "NE",
#                             "references": [
#                                 {
#                                     "id": "NE",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "e43310b1-cb82-4df9-8be5-e9b39637031b",
#                                 "name": "Gillette Stadium",
#                                 "city": "Foxborough",
#                                 "state": "MA",
#                                 "country": "USA",
#                                 "zip": "02035",
#                                 "address": "One Patriot Place",
#                                 "capacity": 68756,
#                                 "surface": "artificial",
#                                 "roof_type": "outdoor"
#                             }
#                         }
#                     ]
#                 },
#                 {
#                     "id": "eb60da78-4eb5-4184-971e-2c5cd4ab4988",
#                     "name": "AFC North",
#                     "alias": "AFC_NORTH",
#                     "teams": [
#                         {
#                             "id": "ad4ae08f-d808-42d5-a1e6-e9bc4e34d123",
#                             "name": "Bengals",
#                             "market": "Cincinnati",
#                             "alias": "CIN",
#                             "references": [
#                                 {
#                                     "id": "CIN",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "b87a1595-d3c8-48ea-8a53-0aab6378a64a",
#                                 "name": "Paul Brown Stadium",
#                                 "city": "Cincinnati",
#                                 "state": "OH",
#                                 "country": "USA",
#                                 "zip": "45202",
#                                 "address": "One Paul Brown Stadium",
#                                 "capacity": 65535,
#                                 "surface": "artificial",
#                                 "roof_type": "outdoor"
#                             }
#                         },
#                         {
#                             "id": "d5a2eb42-8065-4174-ab79-0a6fa820e35e",
#                             "name": "Browns",
#                             "market": "Cleveland",
#                             "alias": "CLE",
#                             "references": [
#                                 {
#                                     "id": "CLV",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "90c38d91-3774-4f5d-82ca-1c806828219f",
#                                 "name": "FirstEnergy Stadium",
#                                 "city": "Cleveland",
#                                 "state": "OH",
#                                 "country": "USA",
#                                 "zip": "44114",
#                                 "address": "100 Alfred Lerner Way",
#                                 "capacity": 71516,
#                                 "surface": "turf",
#                                 "roof_type": "outdoor"
#                             }
#                         },
#                         {
#                             "id": "ebd87119-b331-4469-9ea6-d51fe3ce2f1c",
#                             "name": "Ravens",
#                             "market": "Baltimore",
#                             "alias": "BAL",
#                             "references": [
#                                 {
#                                     "id": "BLT",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "d54faae0-0314-484f-8604-9d8dd08e1149",
#                                 "name": "M&T Bank Stadium",
#                                 "city": "Baltimore",
#                                 "state": "MD",
#                                 "country": "USA",
#                                 "zip": "21230",
#                                 "address": "1101 Russell Street",
#                                 "capacity": 71008,
#                                 "surface": "turf",
#                                 "roof_type": "outdoor"
#                             }
#                         },
#                         {
#                             "id": "cb2f9f1f-ac67-424e-9e72-1475cb0ed398",
#                             "name": "Steelers",
#                             "market": "Pittsburgh",
#                             "alias": "PIT",
#                             "references": [
#                                 {
#                                     "id": "PIT",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "7349a2e6-0ac9-410b-8bd2-ca58c9f7aa34",
#                                 "name": "Heinz Field",
#                                 "city": "Pittsburgh",
#                                 "state": "PA",
#                                 "country": "USA",
#                                 "zip": "15212",
#                                 "address": "100 Art Rooney Avenue",
#                                 "capacity": 65050,
#                                 "surface": "turf",
#                                 "roof_type": "outdoor"
#                             }
#                         }
#                     ]
#                 },
#                 {
#                     "id": "e447e7c0-5997-4bb7-bea3-aaae48aedcb8",
#                     "name": "AFC South",
#                     "alias": "AFC_SOUTH",
#                     "teams": [
#                         {
#                             "id": "82cf9565-6eb9-4f01-bdbd-5aa0d472fcd9",
#                             "name": "Colts",
#                             "market": "Indianapolis",
#                             "alias": "IND",
#                             "references": [
#                                 {
#                                     "id": "IND",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "6ed18563-53e0-46c2-a91d-12d73a16456d",
#                                 "name": "Lucas Oil Stadium",
#                                 "city": "Indianapolis",
#                                 "state": "IN",
#                                 "country": "USA",
#                                 "zip": "46225",
#                                 "address": "500 South Capitol Avenue",
#                                 "capacity": 67000,
#                                 "surface": "artificial",
#                                 "roof_type": "retractable_dome"
#                             }
#                         },
#                         {
#                             "id": "f7ddd7fa-0bae-4f90-bc8e-669e4d6cf2de",
#                             "name": "Jaguars",
#                             "market": "Jacksonville",
#                             "alias": "JAC",
#                             "references": [
#                                 {
#                                     "id": "JAX",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "4c5c036d-dd3d-4183-b595-71a43a97560f",
#                                 "name": "EverBank Field",
#                                 "city": "Jacksonville",
#                                 "state": "FL",
#                                 "country": "USA",
#                                 "zip": "32202",
#                                 "address": "One EverBank Field Drive",
#                                 "capacity": 67246,
#                                 "surface": "turf",
#                                 "roof_type": "outdoor"
#                             }
#                         },
#                         {
#                             "id": "82d2d380-3834-4938-835f-aec541e5ece7",
#                             "name": "Texans",
#                             "market": "Houston",
#                             "alias": "HOU",
#                             "references": [
#                                 {
#                                     "id": "HST",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "6a72e5ca-33d0-40af-8e6b-b32a4d3d9346",
#                                 "name": "NRG Stadium",
#                                 "city": "Houston",
#                                 "state": "TX",
#                                 "country": "USA",
#                                 "zip": "77054",
#                                 "address": "One Reliant Park",
#                                 "capacity": 71054,
#                                 "surface": "artificial",
#                                 "roof_type": "retractable_dome"
#                             }
#                         },
#                         {
#                             "id": "d26a1ca5-722d-4274-8f97-c92e49c96315",
#                             "name": "Titans",
#                             "market": "Tennessee",
#                             "alias": "TEN",
#                             "references": [
#                                 {
#                                     "id": "TEN",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "5295c1b7-c85c-49cb-9569-1707c65324e5",
#                                 "name": "Nissan Stadium",
#                                 "city": "Nashville",
#                                 "state": "TN",
#                                 "country": "USA",
#                                 "zip": "37213",
#                                 "address": "One Titans Way",
#                                 "capacity": 69143,
#                                 "surface": "turf",
#                                 "roof_type": "outdoor"
#                             }
#                         }
#                     ]
#                 },
#                 {
#                     "id": "324decdd-aa1b-4074-8958-c009d8fac31a",
#                     "name": "AFC West",
#                     "alias": "AFC_WEST",
#                     "teams": [
#                         {
#                             "id": "ce92bd47-93d5-4fe9-ada4-0fc681e6caa0",
#                             "name": "Broncos",
#                             "market": "Denver",
#                             "alias": "DEN",
#                             "references": [
#                                 {
#                                     "id": "DEN",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "6589e61d-ef1e-4e30-91b5-9acd2072b8a0",
#                                 "name": "Sports Authority Field at Mile High",
#                                 "city": "Denver",
#                                 "state": "CO",
#                                 "country": "USA",
#                                 "zip": "80204",
#                                 "address": "1701 Mile High Stadium Circle",
#                                 "capacity": 76125,
#                                 "surface": "turf",
#                                 "roof_type": "outdoor"
#                             }
#                         },
#                         {
#                             "id": "1f6dcffb-9823-43cd-9ff4-e7a8466749b5",
#                             "name": "Chargers",
#                             "market": "Los Angeles",
#                             "alias": "LAC",
#                             "references": [
#                                 {
#                                     "id": "LAC",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "feebab00-4a3e-4123-8d7c-ed0dbdd96540",
#                                 "name": "StubHub Center",
#                                 "city": "Carson",
#                                 "state": "CA",
#                                 "country": "USA",
#                                 "zip": "90746",
#                                 "address": "18400 Avalon Boulevard",
#                                 "capacity": 27000,
#                                 "surface": "turf",
#                                 "roof_type": "outdoor"
#                             }
#                         },
#                         {
#                             "id": "6680d28d-d4d2-49f6-aace-5292d3ec02c2",
#                             "name": "Chiefs",
#                             "market": "Kansas City",
#                             "alias": "KC",
#                             "references": [
#                                 {
#                                     "id": "KC",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "2ec4c411-dac2-403d-b091-6b6aa4a0a914",
#                                 "name": "Arrowhead Stadium",
#                                 "city": "Kansas City",
#                                 "state": "MO",
#                                 "country": "USA",
#                                 "zip": "64129",
#                                 "address": "One Arrowhead Drive",
#                                 "capacity": 79451,
#                                 "surface": "turf",
#                                 "roof_type": "outdoor"
#                             }
#                         },
#                         {
#                             "id": "1c1cec48-6352-4556-b789-35304c1a6ae1",
#                             "name": "Raiders",
#                             "market": "Oakland",
#                             "alias": "OAK",
#                             "references": [
#                                 {
#                                     "id": "OAK",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "ba1ad00f-9130-462c-93f9-5612a0015117",
#                                 "name": "Oakland Alameda Coliseum",
#                                 "city": "Oakland",
#                                 "state": "CA",
#                                 "country": "USA",
#                                 "zip": "94621",
#                                 "address": "7000 Coliseum Way",
#                                 "capacity": 53200,
#                                 "surface": "turf",
#                                 "roof_type": "outdoor"
#                             }
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "id": "b1808e5f-d40b-47c0-8af8-5175c0fdcd26",
#             "name": "NFC",
#             "alias": "NFC",
#             "divisions": [
#                 {
#                     "id": "6dab3ca1-b9cb-403f-91dd-b2a3708ab060",
#                     "name": "NFC East",
#                     "alias": "NFC_EAST",
#                     "teams": [
#                         {
#                             "id": "e627eec7-bbae-4fa4-8e73-8e1d6bc5c060",
#                             "name": "Cowboys",
#                             "market": "Dallas",
#                             "alias": "DAL",
#                             "references": [
#                                 {
#                                     "id": "DAL",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "1e84213a-ff1f-4c9d-a003-8ee782b25a40",
#                                 "name": "AT&T Stadium",
#                                 "city": "Arlington",
#                                 "state": "TX",
#                                 "country": "USA",
#                                 "zip": "76011",
#                                 "address": "One Legends Way",
#                                 "capacity": 80000,
#                                 "surface": "artificial",
#                                 "roof_type": "retractable_dome"
#                             }
#                         },
#                         {
#                             "id": "386bdbf9-9eea-4869-bb9a-274b0bc66e80",
#                             "name": "Eagles",
#                             "market": "Philadelphia",
#                             "alias": "PHI",
#                             "references": [
#                                 {
#                                     "id": "PHI",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "4fa8c29c-6626-464c-8540-314ed7535e1b",
#                                 "name": "Lincoln Financial Field",
#                                 "city": "Philadelphia",
#                                 "state": "PA",
#                                 "country": "USA",
#                                 "zip": "19148",
#                                 "address": "1020 Pattison Avenue",
#                                 "capacity": 68532,
#                                 "surface": "turf",
#                                 "roof_type": "outdoor"
#                             }
#                         },
#                         {
#                             "id": "04aa1c9d-66da-489d-b16a-1dee3f2eec4d",
#                             "name": "Giants",
#                             "market": "New York",
#                             "alias": "NYG",
#                             "references": [
#                                 {
#                                     "id": "NYG",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "5d4c85c7-d84e-4e10-bd6a-8a15ebecca5c",
#                                 "name": "MetLife Stadium",
#                                 "city": "East Rutherford",
#                                 "state": "NJ",
#                                 "country": "USA",
#                                 "zip": "07073",
#                                 "address": "One MetLife Stadium Drive",
#                                 "capacity": 82500,
#                                 "surface": "artificial",
#                                 "roof_type": "outdoor"
#                             }
#                         },
#                         {
#                             "id": "22052ff7-c065-42ee-bc8f-c4691c50e624",
#                             "name": "Redskins",
#                             "market": "Washington",
#                             "alias": "WAS",
#                             "references": [
#                                 {
#                                     "id": "WAS",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "7c11bb2d-4a53-4842-b842-0f1c63ed78e9",
#                                 "name": "FedExField",
#                                 "city": "Landover",
#                                 "state": "MD",
#                                 "country": "USA",
#                                 "zip": "20785",
#                                 "address": "1600 FedEx Way",
#                                 "capacity": 83000,
#                                 "surface": "turf",
#                                 "roof_type": "outdoor"
#                             }
#                         }
#                     ]
#                 },
#                 {
#                     "id": "6dc1933f-ca90-46e6-aaf7-9b95cc44306a",
#                     "name": "NFC North",
#                     "alias": "NFC_NORTH",
#                     "teams": [
#                         {
#                             "id": "7b112545-38e6-483c-a55c-96cf6ee49cb8",
#                             "name": "Bears",
#                             "market": "Chicago",
#                             "alias": "CHI",
#                             "references": [
#                                 {
#                                     "id": "CHI",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "d7866605-5ac6-4b3a-90e8-760cc5a26b75",
#                                 "name": "Soldier Field",
#                                 "city": "Chicago",
#                                 "state": "IL",
#                                 "country": "USA",
#                                 "zip": "60605",
#                                 "address": "1410 South Museum Campus Drive",
#                                 "capacity": 61500,
#                                 "surface": "turf",
#                                 "roof_type": "outdoor"
#                             }
#                         },
#                         {
#                             "id": "c5a59daa-53a7-4de0-851f-fb12be893e9e",
#                             "name": "Lions",
#                             "market": "Detroit",
#                             "alias": "DET",
#                             "references": [
#                                 {
#                                     "id": "DET",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "6e3bcf22-277d-4c06-b019-62aded51654f",
#                                 "name": "Ford Field",
#                                 "city": "Detroit",
#                                 "state": "MI",
#                                 "country": "USA",
#                                 "zip": "48226",
#                                 "address": "2000 Brush Street",
#                                 "capacity": 65000,
#                                 "surface": "artificial",
#                                 "roof_type": "dome"
#                             }
#                         },
#                         {
#                             "id": "a20471b4-a8d9-40c7-95ad-90cc30e46932",
#                             "name": "Packers",
#                             "market": "Green Bay",
#                             "alias": "GB",
#                             "references": [
#                                 {
#                                     "id": "GB",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "5a60dd3a-302c-41c6-ab0f-dd335c1103c2",
#                                 "name": "Lambeau Field",
#                                 "city": "Green Bay",
#                                 "state": "WI",
#                                 "country": "USA",
#                                 "zip": "54304",
#                                 "address": "1265 Lombardi Avenue",
#                                 "capacity": 80750,
#                                 "surface": "turf",
#                                 "roof_type": "outdoor"
#                             }
#                         },
#                         {
#                             "id": "33405046-04ee-4058-a950-d606f8c30852",
#                             "name": "Vikings",
#                             "market": "Minnesota",
#                             "alias": "MIN",
#                             "references": [
#                                 {
#                                     "id": "MIN",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "f5ff00d4-1ed8-4918-bf73-13d66d510f98",
#                                 "name": "U.S. Bank Stadium",
#                                 "city": "Minneapolis",
#                                 "state": "MN",
#                                 "country": "USA",
#                                 "zip": "55415",
#                                 "address": "900 S 5th St",
#                                 "capacity": 66200,
#                                 "surface": "turf",
#                                 "roof_type": "dome"
#                             }
#                         }
#                     ]
#                 },
#                 {
#                     "id": "2a46bf95-b036-4c6c-b69f-a80c4b6c46bf",
#                     "name": "NFC South",
#                     "alias": "NFC_SOUTH",
#                     "teams": [
#                         {
#                             "id": "4254d319-1bc7-4f81-b4ab-b5e6f3402b69",
#                             "name": "Buccaneers",
#                             "market": "Tampa Bay",
#                             "alias": "TB",
#                             "references": [
#                                 {
#                                     "id": "TB",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "6fccc39c-80bc-4c81-83d9-2d5a848c8c09",
#                                 "name": "Raymond James Stadium",
#                                 "city": "Tampa",
#                                 "state": "FL",
#                                 "country": "USA",
#                                 "zip": "33607",
#                                 "address": "4201 North Dale Mabry Highway",
#                                 "capacity": 65890,
#                                 "surface": "turf",
#                                 "roof_type": "outdoor"
#                             }
#                         },
#                         {
#                             "id": "e6aa13a4-0055-48a9-bc41-be28dc106929",
#                             "name": "Falcons",
#                             "market": "Atlanta",
#                             "alias": "ATL",
#                             "references": [
#                                 {
#                                     "id": "ATL",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "1f2d393b-2291-4835-a412-0714966ea245",
#                                 "name": "Mercedes-Benz Stadium",
#                                 "city": "Atlanta",
#                                 "state": "GA",
#                                 "country": "USA",
#                                 "zip": "30313",
#                                 "address": "441 Martin Luther King Jr Dr NW",
#                                 "capacity": 71000,
#                                 "surface": "artificial",
#                                 "roof_type": "retractable_dome"
#                             }
#                         },
#                         {
#                             "id": "f14bf5cc-9a82-4a38-bc15-d39f75ed5314",
#                             "name": "Panthers",
#                             "market": "Carolina",
#                             "alias": "CAR",
#                             "references": [
#                                 {
#                                     "id": "CAR",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "39be9ed4-3292-49ac-8699-a381de3a4969",
#                                 "name": "Bank of America Stadium",
#                                 "city": "Charlotte",
#                                 "state": "NC",
#                                 "country": "USA",
#                                 "zip": "28202",
#                                 "address": "800 South Mint Street",
#                                 "capacity": 73778,
#                                 "surface": "turf",
#                                 "roof_type": "outdoor"
#                             }
#                         },
#                         {
#                             "id": "0d855753-ea21-4953-89f9-0e20aff9eb73",
#                             "name": "Saints",
#                             "market": "New Orleans",
#                             "alias": "NO",
#                             "references": [
#                                 {
#                                     "id": "NO",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "3c85d89a-ec66-4983-acd5-1381d6c8673a",
#                                 "name": "Mercedes-Benz Superdome",
#                                 "city": "New Orleans",
#                                 "state": "LA",
#                                 "country": "USA",
#                                 "zip": "70112",
#                                 "address": "1500 Sugar Bowl Drive",
#                                 "capacity": 76468,
#                                 "surface": "artificial",
#                                 "roof_type": "dome"
#                             }
#                         }
#                     ]
#                 },
#                 {
#                     "id": "390d000d-9949-42e6-bf5e-b166dc463675",
#                     "name": "NFC West",
#                     "alias": "NFC_WEST",
#                     "teams": [
#                         {
#                             "id": "f0e724b0-4cbf-495a-be47-013907608da9",
#                             "name": "49ers",
#                             "market": "San Francisco",
#                             "alias": "SF",
#                             "references": [
#                                 {
#                                     "id": "SF",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "24c71dbf-6469-46f1-8165-22005c295c8f",
#                                 "name": "Levi's Stadium",
#                                 "city": "Santa Clara",
#                                 "state": "CA",
#                                 "country": "USA",
#                                 "zip": "95054",
#                                 "address": "4900 Marie P DeBartolo Way",
#                                 "capacity": 68500,
#                                 "surface": "turf",
#                                 "roof_type": "outdoor"
#                             }
#                         },
#                         {
#                             "id": "de760528-1dc0-416a-a978-b510d20692ff",
#                             "name": "Cardinals",
#                             "market": "Arizona",
#                             "alias": "ARI",
#                             "references": [
#                                 {
#                                     "id": "ARZ",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "f8e4d2ab-53f9-4e9f-8c4a-9bc278094a84",
#                                 "name": "University of Phoenix Stadium",
#                                 "city": "Glendale",
#                                 "state": "AZ",
#                                 "country": "USA",
#                                 "zip": "85305",
#                                 "address": "One Cardinals Drive",
#                                 "capacity": 63400,
#                                 "surface": "turf",
#                                 "roof_type": "retractable_dome"
#                             }
#                         },
#                         {
#                             "id": "2eff2a03-54d4-46ba-890e-2bc3925548f3",
#                             "name": "Rams",
#                             "market": "Los Angeles",
#                             "alias": "LA",
#                             "references": [
#                                 {
#                                     "id": "LA",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "4de1fcde-7c65-4145-a874-3753bdd584b7",
#                                 "name": "Los Angeles Memorial Coliseum",
#                                 "city": "Los Angeles",
#                                 "state": "CA",
#                                 "country": "USA",
#                                 "zip": "90037",
#                                 "address": "3911 South Figueroa Street",
#                                 "capacity": 93607,
#                                 "surface": "turf",
#                                 "roof_type": "outdoor"
#                             }
#                         },
#                         {
#                             "id": "3d08af9e-c767-4f88-a7dc-b920c6d2b4a8",
#                             "name": "Seahawks",
#                             "market": "Seattle",
#                             "alias": "SEA",
#                             "references": [
#                                 {
#                                     "id": "SEA",
#                                     "origin": "gsis"
#                                 }
#                             ],
#                             "venue": {
#                                 "id": "c6b9e5df-c9e4-434c-b3e6-83928f11cbda",
#                                 "name": "CenturyLink Field",
#                                 "city": "Seattle",
#                                 "state": "WA",
#                                 "country": "USA",
#                                 "zip": "98134",
#                                 "address": "800 Occidental Avenue South",
#                                 "capacity": 67000,
#                                 "surface": "artificial",
#                                 "roof_type": "outdoor"
#                             }
#                         }
#                     ]
#                 }
#             ]
#         }
#     ],
#     "_comment": "Generation started @ 2018-02-02 00:17:05 +0000 ended @ 2018-02-02 00:17:05 +0000"
# }

# %%
# Setting up sentiments
conf_count = 0
conferences = []
divisions = []
teams = []
team_id = []
venue_name = []
venue_city = []
venue_state = []
venue_capacity = []
venue_surface = []
venue_roof_type = []

# Starting conference gathering loop
for conference in team_id_json['conferences']:

    # Declaring division counter inside so that it resets for each iteration
    div_count = 0
    
    # Starting division gathering loop
    for division in team_id_json['conferences'][conf_count]:
        
        # Declaring teams counter inside so that it resets for each iteration
        team_count = 0
        
        # Starting team gathering loop
        for team in team_id_json['conferences'][conf_count]['divisions'][div_count]:

            # Creating variables for easier handling when appending
            temp_name = team_id_json['conferences'][conf_count]['divisions'][div_count]['teams'][team_count]['name']
            temp_market = team_id_json['conferences'][conf_count]['divisions'][div_count]['teams'][team_count]['market']
            
            # Appending conferences, divisions, team name and team IDs to lists
            conferences.append(team_id_json['conferences'][conf_count]['name'])
            divisions.append(team_id_json['conferences'][conf_count]['divisions'][div_count]['name'])
            teams.append((str(temp_market) + " " + str(temp_name)))
            team_id.append(team_id_json['conferences'][conf_count]['divisions'][div_count]['teams'][team_count]['id'])
            venue_name.append(team_id_json['conferences'][conf_count]['divisions'][div_count]['teams'][team_count]['venue']['name'])
            venue_city.append(team_id_json['conferences'][conf_count]['divisions'][div_count]['teams'][team_count]['venue']['city'])
            venue_state.append(team_id_json['conferences'][conf_count]['divisions'][div_count]['teams'][team_count]['venue']['state'])
            venue_capacity.append(team_id_json['conferences'][conf_count]['divisions'][div_count]['teams'][team_count]['venue']['capacity'])
            venue_surface.append(team_id_json['conferences'][conf_count]['divisions'][div_count]['teams'][team_count]['venue']['surface'])
            venue_roof_type.append(team_id_json['conferences'][conf_count]['divisions'][div_count]['teams'][team_count]['venue']['roof_type'])
            
            # Incrementing teams counter
            team_count += 1
            
        # Incrementing division counter
        div_count += 1
    
    # Incrementing conference counter
    conf_count += 1

# %%
#        conferences.append(team_id_json['conferences']['divisions']['name'])
#print(json.dumps(team_id_json['conferences'][0]['divisions'][0]['teams'][0], indent=4))
#        print(counter)

#       print(json.dumps(team_id_json['conferences'][conf_count]['divisions'][div_count]['name'], indent=4))
#print(json.dumps(team_id_json['conferences'][0]['divisions'][0]['teams'][0]['venue'], indent=4))

# %%
teams_df = pd.DataFrame(list(zip(teams, conferences, divisions, venue_name, venue_city, venue_state, venue_capacity, \
                                 venue_surface, venue_roof_type, team_id)), \
                                 columns=['Team', 'Conference', 'Division', 'Venue Name', 'Venue City', \
                                          'Venue State', 'Venue Capacity', 'Playing Surface', 'Stadium Type', 'Team ID'])
teams_df.head(32)
# Out:
#                     Team Conference   Division  \
# 0          Buffalo Bills        AFC   AFC East
# 1         Miami Dolphins        AFC   AFC East
# 2          New York Jets        AFC   AFC East
# 3   New England Patriots        AFC   AFC East
# 4     Cincinnati Bengals        AFC  AFC North
# 5       Cleveland Browns        AFC  AFC North
# 6       Baltimore Ravens        AFC  AFC North
# 7    Pittsburgh Steelers        AFC  AFC North
# 8     Indianapolis Colts        AFC  AFC South
# 9   Jacksonville Jaguars        AFC  AFC South
# 10        Houston Texans        AFC  AFC South
# 11      Tennessee Titans        AFC  AFC South
# 12        Denver Broncos        AFC   AFC West
# 13  Los Angeles Chargers        AFC   AFC West
# 14    Kansas City Chiefs        AFC   AFC West
# 15       Oakland Raiders        AFC   AFC West
# 16        Dallas Cowboys        NFC   NFC East
# 17   Philadelphia Eagles        NFC   NFC East
# 18       New York Giants        NFC   NFC East
# 19   Washington Redskins        NFC   NFC East
# 20         Chicago Bears        NFC  NFC North
# 21         Detroit Lions        NFC  NFC North
# 22     Green Bay Packers        NFC  NFC North
# 23     Minnesota Vikings        NFC  NFC North
# 24  Tampa Bay Buccaneers        NFC  NFC South
# 25       Atlanta Falcons        NFC  NFC South
# 26     Carolina Panthers        NFC  NFC South
# 27    New Orleans Saints        NFC  NFC South
# 28   San Francisco 49ers        NFC   NFC West
# 29     Arizona Cardinals        NFC   NFC West
# 30      Los Angeles Rams        NFC   NFC West
# 31      Seattle Seahawks        NFC   NFC West
#
#                              Venue Name       Venue City Venue State  \
# 0                         New Era Field     Orchard Park          NY
# 1                     Hard Rock Stadium    Miami Gardens          FL
# 2                       MetLife Stadium  East Rutherford          NJ
# 3                      Gillette Stadium       Foxborough          MA
# 4                    Paul Brown Stadium       Cincinnati          OH
# 5                   FirstEnergy Stadium        Cleveland          OH
# 6                      M&T Bank Stadium        Baltimore          MD
# 7                           Heinz Field       Pittsburgh          PA
# 8                     Lucas Oil Stadium     Indianapolis          IN
# 9                        EverBank Field     Jacksonville          FL
# 10                          NRG Stadium          Houston          TX
# 11                       Nissan Stadium        Nashville          TN
# 12  Sports Authority Field at Mile High           Denver          CO
# 13                       StubHub Center           Carson          CA
# 14                    Arrowhead Stadium      Kansas City          MO
# 15             Oakland Alameda Coliseum          Oakland          CA
# 16                         AT&T Stadium        Arlington          TX
# 17              Lincoln Financial Field     Philadelphia          PA
# 18                      MetLife Stadium  East Rutherford          NJ
# 19                           FedExField         Landover          MD
# 20                        Soldier Field          Chicago          IL
# 21                           Ford Field          Detroit          MI
# 22                        Lambeau Field        Green Bay          WI
# 23                    U.S. Bank Stadium      Minneapolis          MN
# 24                Raymond James Stadium            Tampa          FL
# 25                Mercedes-Benz Stadium          Atlanta          GA
# 26              Bank of America Stadium        Charlotte          NC
# 27              Mercedes-Benz Superdome      New Orleans          LA
# 28                       Levi's Stadium      Santa Clara          CA
# 29        University of Phoenix Stadium         Glendale          AZ
# 30        Los Angeles Memorial Coliseum      Los Angeles          CA
# 31                    CenturyLink Field          Seattle          WA
#
#     Venue Capacity Playing Surface      Stadium Type  \
# 0            73079      artificial           outdoor
# 1            76100            turf           outdoor
# 2            82500      artificial           outdoor
# 3            68756      artificial           outdoor
# 4            65535      artificial           outdoor
# 5            71516            turf           outdoor
# 6            71008            turf           outdoor
# 7            65050            turf           outdoor
# 8            67000      artificial  retractable_dome
# 9            67246            turf           outdoor
# 10           71054      artificial  retractable_dome
# 11           69143            turf           outdoor
# 12           76125            turf           outdoor
# 13           27000            turf           outdoor
# 14           79451            turf           outdoor
# 15           53200            turf           outdoor
# 16           80000      artificial  retractable_dome
# 17           68532            turf           outdoor
# 18           82500      artificial           outdoor
# 19           83000            turf           outdoor
# 20           61500            turf           outdoor
# 21           65000      artificial              dome
# 22           80750            turf           outdoor
# 23           66200            turf              dome
# 24           65890            turf           outdoor
# 25           71000      artificial  retractable_dome
# 26           73778            turf           outdoor
# 27           76468      artificial              dome
# 28           68500            turf           outdoor
# 29           63400            turf  retractable_dome
# 30           93607            turf           outdoor
# 31           67000      artificial           outdoor
#
#                                  Team ID
# 0   768c92aa-75ff-4a43-bcc0-f2798c2e1724
# 1   4809ecb0-abd3-451d-9c4a-92a90b83ca06
# 2   5fee86ae-74ab-4bdd-8416-42a9dd9964f3
# 3   97354895-8c77-4fd4-a860-32e62ea7382a
# 4   ad4ae08f-d808-42d5-a1e6-e9bc4e34d123
# 5   d5a2eb42-8065-4174-ab79-0a6fa820e35e
# 6   ebd87119-b331-4469-9ea6-d51fe3ce2f1c
# 7   cb2f9f1f-ac67-424e-9e72-1475cb0ed398
# 8   82cf9565-6eb9-4f01-bdbd-5aa0d472fcd9
# 9   f7ddd7fa-0bae-4f90-bc8e-669e4d6cf2de
# 10  82d2d380-3834-4938-835f-aec541e5ece7
# 11  d26a1ca5-722d-4274-8f97-c92e49c96315
# 12  ce92bd47-93d5-4fe9-ada4-0fc681e6caa0
# 13  1f6dcffb-9823-43cd-9ff4-e7a8466749b5
# 14  6680d28d-d4d2-49f6-aace-5292d3ec02c2
# 15  1c1cec48-6352-4556-b789-35304c1a6ae1
# 16  e627eec7-bbae-4fa4-8e73-8e1d6bc5c060
# 17  386bdbf9-9eea-4869-bb9a-274b0bc66e80
# 18  04aa1c9d-66da-489d-b16a-1dee3f2eec4d
# 19  22052ff7-c065-42ee-bc8f-c4691c50e624
# 20  7b112545-38e6-483c-a55c-96cf6ee49cb8
# 21  c5a59daa-53a7-4de0-851f-fb12be893e9e
# 22  a20471b4-a8d9-40c7-95ad-90cc30e46932
# 23  33405046-04ee-4058-a950-d606f8c30852
# 24  4254d319-1bc7-4f81-b4ab-b5e6f3402b69
# 25  e6aa13a4-0055-48a9-bc41-be28dc106929
# 26  f14bf5cc-9a82-4a38-bc15-d39f75ed5314
# 27  0d855753-ea21-4953-89f9-0e20aff9eb73
# 28  f0e724b0-4cbf-495a-be47-013907608da9
# 29  de760528-1dc0-416a-a978-b510d20692ff
# 30  2eff2a03-54d4-46ba-890e-2bc3925548f3
# 31  3d08af9e-c767-4f88-a7dc-b920c6d2b4a8

# %%
teams_df.groupby('Stadium Type').mean()
# Out:
#                   Venue Capacity
# Stadium Type
# dome                69222.666667
# outdoor             70448.583333
# retractable_dome    70490.800000

# %%
teams_df.groupby('Stadium Type').describe()
# Out:
#                  Venue Capacity                                                \
#                           count          mean           std      min      25%
# Stadium Type
# dome                        3.0  69222.666667   6303.264339  65000.0  65600.0
# outdoor                    24.0  70448.583333  12560.688713  27000.0  66722.5
# retractable_dome            5.0  70490.800000   6194.079690  63400.0  67000.0
#
#
#                       50%      75%      max
# Stadium Type
# dome              66200.0  71334.0  76468.0
# outdoor           70075.5  76956.5  93607.0
# retractable_dome  71000.0  71054.0  80000.0
