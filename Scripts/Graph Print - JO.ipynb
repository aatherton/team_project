# %% [markdown]
# # Graph Printer - CSE

# %%
import pandas
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

CSV = "actually_final_i_promise.csv"

with open(CSV, "r") as inbox:
    # DATA is the original data
    df = pandas.read_csv(inbox)
college = ['college']

# %%
df = df.dropna(axis=0, subset=college)

result = {}
for each in df["college"].unique():
    result[each] = {}
    ball = df.loc[df["college"] == each]
    result[each]["playercount"] = len(ball["name"].unique())
    result[each]["average score"] = ball["total annual points"].sum() / result[each]["playercount"]
result = pandas.DataFrame(result).transpose()

df['college'] = (df['college'].astype(str).str.lower())

# %%
qb_df = pandas.DataFrame(df[df['Position'] == 'QB'])
rb_df = pandas.DataFrame(df[df['Position'] == 'RB'])
te_df = pandas.DataFrame(df[df['Position'] == 'TE'])
wr_df = pandas.DataFrame(df[df['Position'] == 'WR'])
fb_df = pandas.DataFrame(df[df['Position'] == 'FB'])

qb = pandas.DataFrame(qb_df.groupby(['college'])['total annual points'].sum().sort_values(0, ascending=False).nlargest(20))
rb = pandas.DataFrame(rb_df.groupby(['college'])['total annual points'].sum().sort_values(0, ascending=False).nlargest(20))
wr = pandas.DataFrame(wr_df.groupby(['college'])['total annual points'].sum().sort_values(0, ascending=False).nlargest(20))
te = pandas.DataFrame(te_df.groupby(['college'])['total annual points'].sum().sort_values(0, ascending=False).nlargest(20))
fb = pandas.DataFrame(fb_df.groupby(['college'])['total annual points'].sum().sort_values(0, ascending=False).nlargest(20))

# %%
plt.style.use('seaborn')
qb.index = [x.upper() for x in qb.index]
qb.sort_values(by='total annual points', ascending=True).plot(kind='barh', color='r', legend=None)
plt.title('Top 20 Fantasy Points by College:  QB')
plt.tight_layout()
plt.ylabel('College')
plt.xlabel('Total Points: 2000-2016')
plt.xlim(0,5500)
plt.savefig('Top 20 Fantasy Poducing Colleges - QB.png')
plt.show()

# %%
plt.style.use('seaborn')
rb.index = [x.upper() for x in rb.index]
rb.sort_values(by='total annual points', ascending=True).plot(kind='barh', color='b', legend=None)
plt.title('Top 20 Fantasy Points by College:  RB')
plt.tight_layout()
plt.ylabel('College')
plt.xlabel('Total Points: 2000-2016')
plt.xlim(0,6000)
plt.savefig('Top 20 Fantasy Poducing Colleges - RB.png')
plt.show()

# %%
plt.style.use('seaborn')
te.index = [x.upper() for x in te.index]
te.sort_values(by='total annual points', ascending=True).plot(kind='barh', color='g', legend=None)
plt.title('Top 20 Fantasy Points by College:  TE')
plt.tight_layout()
plt.ylabel('College')
plt.xlabel('Total Points: 2000-2016')
plt.xlim(0,3000)
plt.savefig('Top 20 Fantasy Poducing Colleges - TE.png')
plt.show()

# %%
plt.style.use('seaborn')
wr.index = [x.upper() for x in wr.index]
wr.sort_values(by='total annual points', ascending=True).plot(kind='barh', color='y', legend=None)
plt.title('Top 20 Fantasy Points by College:  WR')
plt.tight_layout()
plt.ylabel('College')
plt.xlabel('Total Points: 2000-2016')
plt.xlim(0,6000)
plt.savefig('Top 20 Fantasy Poducing Colleges - WR.png')
plt.show()

# %%
plt.style.use('seaborn')
fb.index = [x.upper() for x in fb.index]
fb.sort_values(by='total annual points', ascending=True).plot(kind='barh', color='purple', legend=None)
plt.title('Top 20 Fantasy Points by College:  FB')
plt.tight_layout()
plt.ylabel('College')
plt.xlabel('Total Points: 2000-2016')
plt.xlim(0,700)
plt.savefig('Top 20 Fantasy Poducing Colleges - FB.png')
plt.show()

# %%
qb_sum = pandas.DataFrame(qb_df.groupby(['college']).sum())
rb_sum = pandas.DataFrame(rb_df.groupby(['college']).sum())
wr_sum = pandas.DataFrame(wr_df.groupby(['college']).sum())
te_sum = pandas.DataFrame(te_df.groupby(['college']).sum())
fb_sum = pandas.DataFrame(fb_df.groupby(['college']).sum())

# %%
qb_sum['college_avg'] = qb_sum['total annual points']/qb_sum['Games_Played']
rb_sum['college_avg'] = rb_sum['total annual points']/rb_sum['Games_Played']
wr_sum['college_avg'] = wr_sum['total annual points']/wr_sum['Games_Played']
te_sum['college_avg'] = te_sum['total annual points']/te_sum['Games_Played']
fb_sum['college_avg'] = fb_sum['total annual points']/fb_sum['Games_Played']

# %%
plt.style.use('seaborn')
qb_sum.index = [x.upper() for x in qb_sum.index]
ax = qb_sum['college_avg'].sort_values(ascending=False).head(20)
ax.sort_values(ascending=True).plot(kind='barh', color='r', legend=None)
plt.title('Top 20 Fantasy Points Per Game by College: QB')
plt.ylabel('College')
plt.xlabel('Average Points For Years 2000-2016')
plt.xlim(0,20)
plt.savefig('Top 20 Average Fantasy Points by College - QB.png')
plt.show()

# %%
plt.style.use('seaborn')
rb_sum.index = [x.upper() for x in rb_sum.index]
ax = rb_sum['college_avg'].sort_values(ascending=False).head(20)
ax.sort_values(ascending=True).plot(kind='barh', color='b', legend=None)
plt.title('Top 20 Fantasy Points Per Game by College: RB')
plt.ylabel('College')
plt.xlabel('Average Points For Years 2000-2016')
plt.xlim(0,16)
plt.savefig('Top 20 Average Fantasy Points by College - RB.png')
plt.show()

# %%
plt.style.use('seaborn')
te_sum.index = [x.upper() for x in te_sum.index]
ax = te_sum['college_avg'].sort_values(ascending=False).head(20)
ax.sort_values(ascending=True).plot(kind='barh', color='g', legend=None)
plt.title('Top 20 Fantasy Points Per Game by College: TE')
plt.ylabel('College')
plt.xlabel('Average Points For Years 2000-2016')
plt.xlim(0,7)
plt.savefig('Top 20 Average Fantasy Points by College - TE.png')
plt.show()

# %%
plt.style.use('seaborn')
wr_sum.index = [x.upper() for x in wr_sum.index]
ax = wr_sum['college_avg'].sort_values(ascending=False).head(20)
ax.sort_values(ascending=True).plot(kind='barh', color='y', legend=None)
plt.title('Top 20 Fantasy Points Per Game by College: WR')
plt.ylabel('College')
plt.xlabel('Average Points For Years 2000-2016')
plt.xlim(0,13)
plt.savefig('Top 20 Average Fantasy Points by College - WR.png')
plt.show()

# %%
plt.style.use('seaborn')
fb_sum.index = [x.upper() for x in fb_sum.index]
ax = fb_sum['college_avg'].sort_values(ascending=False).head(20)
ax.sort_values(ascending=True).plot(kind='barh', color='purple', legend=None)
plt.title('Top 20 Fantasy Points Per Game by College: FB')
plt.ylabel('College')
plt.xlabel('Average Points For Years 2000-2016')
plt.xlim(0,9)
plt.savefig('Top 20 Average Fantasy Points by College - FB.png')
plt.show()

# %%
wr_sum['college_avg'].sort_values(ascending=False).head(20)
# Out:
# TENNESSEE-CHATTANOOGA       12.856688
# CENTRAL MICHIGAN            11.828696
# ITAWAMBA                     9.492632
# FLORIDA INTERNATIONAL        9.385106
# OKLAHOMA STATE               8.646541
# UNLV                         8.138889
# UTAH                         7.983032
# HOFSTRA                      7.881034
# ALABAMA-BIRMINGHAM           7.735681
# WESTERN MICHIGAN             7.688199
# GEORGIA TECH                 7.624831
# ALABAMA                      7.560185
# MISSISSIPPI VALLEY STATE     7.420988
# OREGON STATE                 7.244479
# PITTSBURGH                   7.227218
# MARSHALL                     7.166650
# NORTHERN COLORADO            6.911392
# SYRACUSE                     6.844272
# MIAMI                        6.727763
# GEORGIA                      6.715464
# Name: college_avg, dtype: float64

# %%
qb_count = pandas.DataFrame(qb_df['college'].value_counts())
qb_count.sort_index(inplace=True)
qb_count.rename(index=str, columns={'college': 'college_count'}, inplace=True)
qb_sum = pandas.merge(qb_sum, qb_count, right_index=True, left_index=True)
qb_sum

#qb_sum['college_count'] = qb_sum['total annual points']/qb_sum['Games_Played']
#rb_sum['college_count'] = rb_sum['total annual points']/rb_sum['Games_Played']
#wr_sum['college_count'] = wr_sum['total annual points']/wr_sum['Games_Played']
#te_sum['college_count'] = te_sum['total annual points']/te_sum['Games_Played']
#fb_sum['college_count'] = fb_sum['total annual points']/fb_sum['Games_Played']
# Out:
#                      Unnamed: 0  Unnamed: 0_x   Year  Games_Played  \
# college
# alabama                    7189          7189  10074            13
# alabama state             76262         76262  20105            59
# alabama-birmingham        55372         55372  16108            86
# arizona                   26353         26353  10072            38
# arizona state             24387         24387  12087            42
# arkansas                  39080         39080  24172            21
# arkansas-pine bluff        5640          5640   4002             0
# auburn                    75658         75658  18099           115
# ball state                10616         10616   4024             0
# baylor                    28999         28999  16118            52
# boise state               30592         30592  10071             3
# boston college           211850        211850  60256           368
# bowling green state        1705          1705   2004             0
# brigham young             54740         54740  20090            20
# california               136451        136451  46239           231
# california (pa)            9805          9805   2011             0
# central florida           75005         75005  28107           166
# central michigan           9831          9831   6038             2
# central washington        56645         56645  26079           117
# clemson                   35701         35701  14098            28
# colorado                  48842         48842  24030           145
# colorado state            16244         16244   6026             3
# connecticut               72131         72131  24126            26
# dartmouth                  2604          2604  12015            64
# delaware                  48611         48611  38186           212
# duke                      29203         29203  14094             9
# east carolina             28451         28451  20067            87
# eastern illinois          85264         85264  38212           179
# eastern michigan          34925         34925  22066            58
# florida                   94337         94337  42142           110
# ...                         ...           ...    ...           ...
# syracuse                  92808         92808  34141           160
# temple                    13055         13055   4003             6
# tennessee                 76728         76728  50214           242
# texas                     63071         63071  28159            96
# texas a&m                  6755          6755  14099            91
# texas christian           20811         20811  16114           114
# texas tech                35023         35023  12055             6
# texas-el paso             17840         17840  12066             5
# toledo                    34601         34601  18090            37
# tulane                    41193         41193  10075             0
# tulsa                     34592         34592  16031            77
# uc davis                   8908          8908   2001             0
# ucla                      32927         32927  12049            36
# unlv                       6895          6895   4001            12
# usc                       67270         67270  24072            63
# utah                      97610         97610  30144           165
# vanderbilt                63932         63932  24138           153
# virginia                  71471         71471  28147           145
# virginia tech             88310         88310  42209           202
# washington                50416         50416  20056            77
# washington state          23641         23641  22039            98
# weber state               29994         29994  10024            24
# wesley                    25142         25142   8065             1
# west texas a&m             5137          5137   2014             0
# west virginia             16014         16014  14097            48
# western kentucky            627           627   2016             0
# william & mary             7377          7377   2010             0
# williams                   9232          9232   2000             0
# wisconsin                121115        121115  38224           122
# wyoming                    9847          9847   6018             0
#
#                      passing yards  passing touchdowns  passing interceptions  \
# college
# alabama                      45.36                  28                     -6
# alabama state               290.52                 156                    -70
# alabama-birmingham           35.52                  12                    -12
# arizona                     308.00                 216                    -38
# arizona state               246.84                 124                    -54
# arkansas                     73.40                  36                    -20
# arkansas-pine bluff           0.00                   0                      0
# auburn                     1004.32                 632                   -188
# ball state                    0.00                   0                      0
# baylor                      413.44                 184                    -72
# boise state                  31.16                  16                    -12
# boston college             3204.88                1916                   -564
# bowling green state           0.00                   0                      0
# brigham young                71.48                  16                    -26
# california                 2057.08                1564                   -280
# california (pa)               0.00                   0                      0
# central florida            1563.24                 956                   -340
# central michigan              0.08                   0                      0
# central washington          994.04                 552                   -278
# clemson                     166.48                 120                    -32
# colorado                    331.76                 160                    -88
# colorado state                0.28                   0                      0
# connecticut                 125.28                  60                    -26
# dartmouth                   444.20                 268                   -126
# delaware                   1981.00                1160                   -332
# duke                         52.28                  20                    -10
# east carolina               640.12                 356                   -108
# eastern illinois           1457.32                1040                   -244
# eastern michigan            278.00                 148                    -78
# florida                     624.28                 372                   -174
# ...                            ...                 ...                    ...
# syracuse                   1458.24                 908                   -220
# temple                        8.28                  12                    -10
# tennessee                  2573.20                1952                   -420
# texas                       582.00                 288                   -148
# texas a&m                   805.20                 452                   -146
# texas christian            1027.16                 672                   -188
# texas tech                   12.84                   0                     -2
# texas-el paso                 2.64                   0                     -4
# toledo                      162.28                  84                    -48
# tulane                        0.00                   0                      0
# tulsa                       334.56                 200                    -86
# uc davis                      0.00                   0                      0
# ucla                        205.24                  96                    -72
# unlv                         56.88                  36                    -12
# usc                         331.36                 132                    -76
# utah                       1315.68                 744                   -214
# vanderbilt                 1405.32                 908                   -320
# virginia                    994.68                 532                   -180
# virginia tech              1260.80                 736                   -212
# washington                  493.24                 244                   -120
# washington state            780.20                 424                   -178
# weber state                  20.60                  12                     -4
# wesley                        0.44                   0                      0
# west texas a&m                0.00                   0                      0
# west virginia               246.96                 116                    -72
# western kentucky              0.00                   0                      0
# william & mary                0.00                   0                      0
# williams                      0.00                   0                      0
# wisconsin                   966.80                 676                   -132
# wyoming                       0.00                   0                      0
#
#                      rushing yards  rushing touchdowns  fumbles  \
# college
# alabama                        6.1                   0       -4
# alabama state                 63.6                  36      -48
# alabama-birmingham            32.6                  24       -4
# arizona                       33.0                  24      -44
# arizona state                 24.5                  24      -22
# arkansas                      -0.5                   6       -2
# arkansas-pine bluff            0.0                   0        0
# auburn                       434.4                 324      -90
# ball state                     0.0                   0        0
# baylor                       174.4                  60      -76
# boise state                   -0.1                   0       -2
# boston college               239.9                  84     -252
# bowling green state            0.0                   0        0
# brigham young                  5.0                  18      -30
# california                   323.3                 174     -240
# california (pa)                0.0                   0        0
# central florida              405.6                 246     -278
# central michigan               1.3                   0        0
# central washington            82.4                  54     -178
# clemson                       41.7                  18      -20
# colorado                     148.9                 108      -68
# colorado state                 4.8                   6        0
# connecticut                    3.4                   0      -22
# dartmouth                     83.4                  66      -56
# delaware                     172.6                 150     -226
# duke                           5.1                   6      -14
# east carolina                174.6                 102      -88
# eastern illinois              64.1                  36     -130
# eastern michigan              32.1                  18      -36
# florida                      116.3                  96     -106
# ...                            ...                 ...      ...
# syracuse                     314.6                 174     -176
# temple                        10.4                   0       -8
# tennessee                     60.7                  96     -142
# texas                        187.9                  84     -118
# texas a&m                    132.4                  42     -106
# texas christian              105.0                 108      -68
# texas tech                     0.7                   0       -2
# texas-el paso                  0.3                   0        0
# toledo                        32.9                   0      -40
# tulane                         0.0                   0        0
# tulsa                         16.1                  18      -56
# uc davis                       0.0                   0        0
# ucla                          60.7                  30      -28
# unlv                          12.9                  12      -16
# usc                           73.1                  24      -46
# utah                         249.4                  90     -146
# vanderbilt                   168.2                  54     -190
# virginia                      36.0                  24      -88
# virginia tech                782.0                 306     -230
# washington                    85.7                  30      -66
# washington state              39.7                  60     -138
# weber state                   -0.9                   0       -6
# wesley                         0.0                   0        0
# west texas a&m                 0.0                   0        0
# west virginia                 74.0                  42      -40
# western kentucky               0.0                   0        0
# william & mary                 0.0                   0        0
# williams                       0.0                   0        0
# wisconsin                    333.2                 102     -122
# wyoming                        0.0                   0        0
#
#                      receiving yards  receiving touchdowns  receptions  \
# college
# alabama                          0.0                     0           0
# alabama state                    0.0                     0           0
# alabama-birmingham               6.1                     0           8
# arizona                          0.0                     0           0
# arizona state                   -1.4                     0           1
# arkansas                         0.0                     0           0
# arkansas-pine bluff              0.0                     0           0
# auburn                           3.7                     0           3
# ball state                       0.0                     0           0
# baylor                           0.0                     0           0
# boise state                      0.0                     0           0
# boston college                   0.0                     0           0
# bowling green state              0.0                     0           0
# brigham young                    0.0                     0           0
# california                      -0.1                     0           1
# california (pa)                  0.0                     0           0
# central florida                  2.0                     6           2
# central michigan                 0.0                     0           0
# central washington               0.9                     0           1
# clemson                          1.0                     0           0
# colorado                         0.0                     0           0
# colorado state                   0.0                     0           0
# connecticut                      0.0                     0           0
# dartmouth                        0.0                     0           0
# delaware                         3.5                     0           2
# duke                             0.0                     0           0
# east carolina                   -0.6                     0           1
# eastern illinois                 0.7                     0           3
# eastern michigan                 0.0                     0           0
# florida                         -1.7                     0           2
# ...                              ...                   ...         ...
# syracuse                        -0.1                     0           4
# temple                           0.0                     0           0
# tennessee                       -0.2                     0           1
# texas                            0.8                     0           2
# texas a&m                        0.5                     0           2
# texas christian                  1.8                     6           1
# texas tech                       0.0                     0           0
# texas-el paso                    0.0                     0           0
# toledo                           0.0                     0           0
# tulane                           0.0                     0           0
# tulsa                            0.0                     0           0
# uc davis                         0.0                     0           0
# ucla                             1.0                     0           1
# unlv                             0.0                     0           0
# usc                             -0.6                     0           1
# utah                            -0.7                     0           3
# vanderbilt                       0.0                     0           0
# virginia                        -0.6                     0           1
# virginia tech                    1.1                     0           4
# washington                      -0.4                     0           1
# washington state                 0.0                     0           0
# weber state                      0.0                     0           0
# wesley                           0.0                     0           0
# west texas a&m                   0.0                     0           0
# west virginia                    1.3                     0           1
# western kentucky                 0.0                     0           0
# william & mary                   0.0                     0           0
# williams                         0.0                     0           0
# wisconsin                        3.1                     6           3
# wyoming                          0.0                     0           0
#
#                      kick returns  punt returns  total annual points  \
# college
# alabama                         0             0                69.46
# alabama state                   0             0               428.12
# alabama-birmingham              0             0                94.22
# arizona                         0             0               499.00
# arizona state                   0             0               341.94
# arkansas                        0             0                92.90
# arkansas-pine bluff             0             0                 0.00
# auburn                          0             0              2120.42
# ball state                      0             0                 0.00
# baylor                          0             0               683.84
# boise state                     0             0                33.06
# boston college                  0             0              4628.78
# bowling green state             0             0                 0.00
# brigham young                   0             0                54.48
# california                      0             0              3598.28
# california (pa)                 0             0                 0.00
# central florida                 0             0              2560.84
# central michigan                0             0                 1.38
# central washington              0             0              1227.34
# clemson                         0             0               295.18
# colorado                        0             0               592.66
# colorado state                  0             0                11.08
# connecticut                     0             0               140.68
# dartmouth                       0             0               679.60
# delaware                        0             0              2909.10
# duke                            0             0                59.38
# east carolina                   0             0              1076.12
# eastern illinois                0             0              2224.12
# eastern michigan                0             0               362.10
# florida                         0             0               926.88
# ...                           ...           ...                  ...
# syracuse                        0             0              2458.74
# temple                          0             0                12.68
# tennessee                       0             0              4119.70
# texas                           0             0               876.70
# texas a&m                       0             0              1180.10
# texas christian                 0             0              1663.96
# texas tech                      0             0                 9.54
# texas-el paso                   0             0                -1.06
# toledo                          0             0               191.18
# tulane                          0             0                 0.00
# tulsa                           0             0               426.66
# uc davis                        0             0                 0.00
# ucla                            0             0               292.94
# unlv                            0             0                89.78
# usc                             0             0               437.86
# utah                            0             0              2038.38
# vanderbilt                      0             0              2025.52
# virginia                        0             0              1318.08
# virginia tech                   0             0              2643.90
# washington                      0             0               666.54
# washington state                0             0               987.90
# weber state                     0             0                21.70
# wesley                          0             0                 0.44
# west texas a&m                  0             0                 0.00
# west virginia                   0             0               368.26
# western kentucky                0             0                 0.00
# william & mary                  0             0                 0.00
# williams                        0             0                 0.00
# wisconsin                       0             0              1833.10
# wyoming                         0             0                 0.00
#
#                      Unnamed: 0_y  college_avg  college_count
# college
# alabama                      3036     5.343077              5
# alabama state                 940     7.256271             10
# alabama-birmingham           1184     1.095581              8
# arizona                      8125    13.131579              5
# arizona state                8028     8.141429              6
# arkansas                     9706     4.423810             12
# arkansas-pine bluff          2104          NaN              2
# auburn                      21731    18.438435              9
# ball state                   3190          NaN              2
# baylor                       5329    13.150769              8
# boise state                  8830    11.020000              5
# boston college              44836    12.578207             30
# bowling green state           716          NaN              1
# brigham young               11467     2.724000             10
# california                  41094    15.576970             23
# california (pa)              2646          NaN              1
# central florida              7190    15.426747             14
# central michigan             3054     0.690000              3
# central washington           7787    10.490085             13
# clemson                      6183    10.542143              7
# colorado                    15846     4.087310             12
# colorado state               5084     3.693333              3
# connecticut                 13308     5.410769             12
# dartmouth                    1020    10.618750              6
# delaware                    18065    13.722170             19
# duke                         5275     6.597778              7
# east carolina                4060    12.369195             10
# eastern illinois            27038    12.425251             19
# eastern michigan            10516     6.243103             11
# florida                     15827     8.426182             21
# ...                           ...          ...            ...
# syracuse                    27812    15.367125             17
# temple                       4022     2.113333              2
# tennessee                   26228    17.023554             25
# texas                       14384     9.132292             14
# texas a&m                    2926    12.968132              7
# texas christian              7178    14.596140              8
# texas tech                  10946     1.590000              6
# texas-el paso                3756    -0.212000              6
# toledo                       5778     5.167027              9
# tulane                      11570          NaN              5
# tulsa                        2668     5.541039              8
# uc davis                     2506          NaN              1
# ucla                         8650     8.137222              6
# unlv                         1682     7.481667              2
# usc                          9232     6.950159             12
# utah                        22059    12.353818             15
# vanderbilt                   3804    13.238693             12
# virginia                    12908     9.090207             14
# virginia tech                6583    13.088614             21
# washington                  16292     8.656364             10
# washington state             4432    10.080612             11
# weber state                  1690     0.904167              5
# wesley                       3256     0.440000              4
# west texas a&m               1763          NaN              1
# west virginia                2574     7.672083              7
# western kentucky              303          NaN              1
# william & mary               2238          NaN              1
# williams                     2557          NaN              1
# wisconsin                   30303    15.025410             19
# wyoming                       672          NaN              3
#
# [124 rows x 19 columns]
